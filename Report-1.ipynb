# %%
## Go back to the brief, make sure everything is ticked off
## It's why WHY that's important. Why by expirimentation and/or referencing. 
# Why boxplot, why colours, why titles, etc. etc. in the report (for David, 200-300 words) in the markdown for sam. Sam only read the notebook I think.  
## There's a template for CA3 
 # Intro, main body, conclusion 
# Resources on Student Success 
# See Research papers on David's Moodle page as samples for structure
# Go back to the feedback form CA1

# %%
# Fix Github to Public

# %%
#  Reading - what impacts the price of wheat 
# https://www.ers.usda.gov/webdocs/publications/47264/51088_tb1878b.pdf?v=0 
## https://www.economicshelp.org/blog/168151/economics/factors-determining-the-price-of-wheat/#:~:text=The%20price%20of%20wheat%20is,climate%20factors%20affecting%20the%20supply.

# %%
import pandas as pd
import matplotlib as mpl
import numpy as np

# %%
# Import all economic datasets


df1 = pd.read_csv("DATA/DP_LIVE_06012023190448991.csv")
df2 = pd.read_csv("DATA/DP_LIVE_06012023190508679.csv")
df3 = pd.read_csv("DATA/DP_LIVE_06012023190521038.csv")
df4 = pd.read_csv("DATA/DP_LIVE_06012023190621335.csv")
df5 = pd.read_csv("DATA/DP_LIVE_06012023190631007.csv")
df6 = pd.read_csv("DATA/DP_LIVE_06012023190759570.csv")
df7 = pd.read_csv("DATA/DP_LIVE_06012023190909741.csv")
df8 = pd.read_csv("DATA/DP_LIVE_06012023191011288.csv")
df9 = pd.read_csv("DATA/DP_LIVE_06012023191646976.csv")
df10 = pd.read_csv("DATA/DP_LIVE_06012023192018179.csv")
df11 = pd.read_csv("DATA/DP_LIVE_06012023192105335.csv")
df12 = pd.read_csv("DATA/DP_LIVE_06012023214944235.csv")
df13 = pd.read_csv("DATA/DP_LIVE_06012023215221798.csv")
df14 = pd.read_csv("DATA/PPP-EU.csv")

# %%
# Monthly = df1 (CCI), df2 (CLI) , df3 (CLI)

# %%
# Quarterly = df11 (HHI)

# %%
# Annually = df4 (GDP), df5 (GDP), df6 (GFCFSector), df7 (cropyield), df8, (aggsupp), df9 (exch), df10 (GNI), df11, (grossAJD), df 12 (YRLIFELOST), df13 (oilprod), df14 (ppp)

# %%
df5.head()
# Out:
#   LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME         Value Flag Codes
# 0      AUT       GDP     TOT  USD_CAP         A  2000  29380.031110        NaN
# 1      AUT       GDP     TOT  USD_CAP         A  2001  29707.462264        NaN
# 2      AUT       GDP     TOT  USD_CAP         A  2002  31178.051444        NaN
# 3      AUT       GDP     TOT  USD_CAP         A  2003  32158.225907        NaN
# 4      AUT       GDP     TOT  USD_CAP         A  2004  33784.432645        NaN

# %%
df_gdp = df5

# %%
print(df5['LOCATION'].unique())
# Out:
# ['AUT' 'BEL' 'CAN' 'CZE' 'DNK' 'FIN' 'FRA' 'DEU' 'GRC' 'HUN' 'IRL' 'ITA'
#  'JPN' 'LUX' 'NLD' 'POL' 'PRT' 'SVK' 'ESP' 'SWE' 'GBR' 'USA' 'EST' 'SVN'
#  'OECD' 'LVA' 'LTU' 'BGR' 'HRV' 'CYP' 'MLT' 'ROU']

# %%
df_gdp_ire = df5[df5['LOCATION'] == "IRL"] 
df_gdp_ire.head(500)
# Out:
#     LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME          Value  \
# 220      IRL       GDP     TOT  USD_CAP         A  2000   30217.135247
# 221      IRL       GDP     TOT  USD_CAP         A  2001   32592.934780
# 222      IRL       GDP     TOT  USD_CAP         A  2002   35222.881959
# 223      IRL       GDP     TOT  USD_CAP         A  2003   36280.363177
# 224      IRL       GDP     TOT  USD_CAP         A  2004   38761.602107
# 225      IRL       GDP     TOT  USD_CAP         A  2005   40465.540236
# 226      IRL       GDP     TOT  USD_CAP         A  2006   44264.939920
# 227      IRL       GDP     TOT  USD_CAP         A  2007   46765.460776
# 228      IRL       GDP     TOT  USD_CAP         A  2008   44105.305617
# 229      IRL       GDP     TOT  USD_CAP         A  2009   41438.863041
# 230      IRL       GDP     TOT  USD_CAP         A  2010   43213.491477
# 231      IRL       GDP     TOT  USD_CAP         A  2011   45100.566928
# ...

# %%
print(df5['MEASURE'].unique())
# Out:
# ['USD_CAP']

# %%
# Combine to make master economic set. As all in the same format, we can stack the DataFrames on top of each other
df_econ = pd.concat([df4, df5, df6, df7, df8, df9, df10, df12, df13], axis=0)

# %%
df_econ.describe()
# Out:
#                TIME         Value
# count  33379.000000  3.337900e+04
# mean    2008.754247  1.401094e+04
# std       10.735205  6.024846e+04
# min     1986.000000 -2.635270e+05
# 25%     2000.000000  2.034000e+00
# 50%     2009.000000  7.361200e+01
# 75%     2017.000000  4.776456e+03
# max     2030.000000  1.312195e+06

# %%
df_econ.head(50)
# Out:
#    LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME          Value  \
# 0       AUT       GDP     TOT  USD_CAP         A  2018   56956.110562
# 1       AUT       GDP     TOT  USD_CAP         A  2019   59719.331647
# 2       AUT       GDP     TOT  USD_CAP         A  2020   57253.300563
# 3       AUT       GDP     TOT  USD_CAP         A  2021   59976.264665
# 4       BEL       GDP     TOT  USD_CAP         A  2018   52530.841510
# 5       BEL       GDP     TOT  USD_CAP         A  2019   55800.825988
# 6       BEL       GDP     TOT  USD_CAP         A  2020   54539.032525
# 7       BEL       GDP     TOT  USD_CAP         A  2021   58816.266983
# 8       CAN       GDP     TOT  USD_CAP         A  2018   49992.811418
# 9       CAN       GDP     TOT  USD_CAP         A  2019   49832.297981
# 10      CAN       GDP     TOT  USD_CAP         A  2020   47228.372488
# 11      CAN       GDP     TOT  USD_CAP         A  2021   53074.088264
# ...

# %%
df_econ.TIME.unique()
# Out:
# array([2018, 2019, 2020, 2021, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017,
#        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2022,
#        2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 1986, 1987, 1988,
#        1989], dtype=int64)

# %%
df_econ.INDICATOR.unique()
# Out:
# array(['GDP', 'GFCFSECTOR', 'CROPYIELD', 'AGRSUPP', 'EXCH', 'GNI',
#        'YRLIFELOST', 'OILPROD'], dtype=object)

# %%
df_econ.SUBJECT.unique()
# Out:
# array(['TOT', 'GG', 'RICE', 'WHEAT', 'MAIZE', 'SOYBEAN', 'TSE', 'PSE',
#        'CSE', 'GSSE'], dtype=object)

# %%
df_econ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33379 entries, 0 to 683
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    33379 non-null  object
#  1   INDICATOR   33379 non-null  object
#  2   SUBJECT     33379 non-null  object
#  3   MEASURE     33379 non-null  object
#  4   FREQUENCY   33379 non-null  object
#  5   TIME        33379 non-null  int64
#  6   Value       33379 non-null  float64
#  7   Flag Codes  197 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.3+ MB

# %%
# Remove dupliates 

df_econ2 = df_econ.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)

# %%
df_econ2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33251 entries, 0 to 683
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    33251 non-null  object
#  1   INDICATOR   33251 non-null  object
#  2   SUBJECT     33251 non-null  object
#  3   MEASURE     33251 non-null  object
#  4   FREQUENCY   33251 non-null  object
#  5   TIME        33251 non-null  int64
#  6   Value       33251 non-null  float64
#  7   Flag Codes  167 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.3+ MB

# %%
df_econ.LOCATION.unique()
# Out:
# array(['AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU', 'GRC',
#        'HUN', 'IRL', 'ITA', 'JPN', 'LUX', 'NLD', 'POL', 'PRT', 'SVK',
#        'ESP', 'SWE', 'GBR', 'USA', 'EST', 'SVN', 'OECD', 'LVA', 'LTU',
#        'BGR', 'HRV', 'CYP', 'MLT', 'ROU', 'AUS', 'KOR', 'MEX', 'NZL',
#        'TUR', 'ARG', 'BRA', 'CHL', 'CHN', 'COL', 'EGY', 'ETH', 'IND',
#        'IDN', 'IRN', 'KAZ', 'MYS', 'NGA', 'PAK', 'PRY', 'PER', 'PHL',
#        'RUS', 'SAU', 'ZAF', 'THA', 'UKR', 'VNM', 'WLD', 'BRICS', 'NOR',
#        'CHE', 'ISR', 'ISL', 'EU', 'CRI'], dtype=object)

# %%
# Add dataset to lookup to if a country is EU  or NOT. 
df_eulookup = pd.read_csv("DATA/EU_countries.csv")

df_eulookup.head(50)
# Out:
#    LOCATION       EU_Country  EU
# 0       AUT          Austria   1
# 1       BEL          Belgium   1
# 2       BGR         Bulgaria   1
# 3       HRV          Croatia   1
# 4       CYP           Cyprus   1
# 5       CZE   Czech Republic   1
# 6       DNK          Denmark   1
# 7       EST          Estonia   1
# 8       FIN          Finland   1
# 9       FRA           France   1
# 10      DEU          Germany   1
# 11      GRC           Greece   1
# 12      HUN          Hungary   1
# 13      IRL          Ireland   1
# 14      ITA            Italy   1
# 15      LVA           Latvia   1
# 16      LTU        Lithuania   1
# 17      LUX       Luxembourg   1
# 18      MLT            Malta   1
# 19      NLD      Netherlands   1
# 20      POL           Poland   1
# 21      PRT         Portugal   1
# 22      ROU          Romania   1
# 23      SVK  Slovak Republic   1
# 24      SVN         Slovenia   1
# 25      ESP            Spain   1
# 26      SWE           Sweden   1

# %%
# Add colum to say if Location is EU country, OECD benchark or otherwise. 
df_econ3 = df_econ2.join(df_eulookup.set_index('LOCATION'), on='LOCATION')
df_econ3.tail(100)
# Out:
#     LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME  Value Flag Codes  \
# 584      EST   OILPROD     TOT    KTOE         A  2008    0.0        NaN
# 585      EST   OILPROD     TOT    KTOE         A  2009    0.0        NaN
# 586      EST   OILPROD     TOT    KTOE         A  2010    0.0        NaN
# 587      EST   OILPROD     TOT    KTOE         A  2011    0.0        NaN
# 588      EST   OILPROD     TOT    KTOE         A  2012    0.0        NaN
# ..       ...       ...     ...     ...       ...   ...    ...        ...
# 679      CRI   OILPROD     TOT    KTOE         A  2013    0.0        NaN
# 680      CRI   OILPROD     TOT    KTOE         A  2014    0.0        NaN
# 681      CRI   OILPROD     TOT    KTOE         A  2015    0.0        NaN
# 682      CRI   OILPROD     TOT    KTOE         A  2016    0.0        NaN
# 683      CRI   OILPROD     TOT    KTOE         A  2017    0.0        NaN
#
#     EU_Country   EU
# 584    Estonia  1.0
# 585    Estonia  1.0
# 586    Estonia  1.0
# ...

# %%
df_econ3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33251 entries, 0 to 683
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    33251 non-null  object
#  1   INDICATOR   33251 non-null  object
#  2   SUBJECT     33251 non-null  object
#  3   MEASURE     33251 non-null  object
#  4   FREQUENCY   33251 non-null  object
#  5   TIME        33251 non-null  int64
#  6   Value       33251 non-null  float64
#  7   Flag Codes  167 non-null    object
#  8   EU_Country  2948 non-null   object
#  9   EU          2948 non-null   float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 2.8+ MB

# %%
df_econ3.TIME.unique()
# Out:
# array([2018, 2019, 2020, 2021, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017,
#        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2022,
#        2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 1986, 1987, 1988,
#        1989], dtype=int64)

# %%
# Mask formula to remove some that contains "-" from the new df

# year_mask = (df_econ3.TIME.str.find("-")==-1)
# df_econ3_year = df_econ3[year_mask]

# %%
# df_econ3_year.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 df_econ3_year.head()
#
# NameError: name 'df_econ3_year' is not defined

# %%
df_econ4 = df_econ3.astype({'TIME':'int'})

# %%
df_econ5.TIME.unique()

# %%
# from pandas.core.reshape.pivot import pivot

# %%
pd.pivot_table(df_econ3, values = 'Value', index=['LOCATION','TIME'], columns = 'INDICATOR').reset_index()
# Out:
# INDICATOR LOCATION  TIME  AGRSUPP    CROPYIELD  EXCH  GDP  GFCFSECTOR  GNI  \
# 0              ARG  1990      NaN  3592.324250   NaN  NaN         NaN  NaN
# 1              ARG  1991      NaN  3685.865750   NaN  NaN         NaN  NaN
# 2              ARG  1992      NaN  3708.984667   NaN  NaN         NaN  NaN
# 3              ARG  1993      NaN  3782.307667   NaN  NaN         NaN  NaN
# 4              ARG  1994      NaN  4102.401917   NaN  NaN         NaN  NaN
# ...            ...   ...      ...          ...   ...  ...         ...  ...
# 2366           ZAF  2026      NaN  2143.978167   NaN  NaN         NaN  NaN
# 2367           ZAF  2027      NaN  2175.352500   NaN  NaN         NaN  NaN
# 2368           ZAF  2028      NaN  2206.567750   NaN  NaN         NaN  NaN
# 2369           ZAF  2029      NaN  2239.788250   NaN  NaN         NaN  NaN
# 2370           ZAF  2030      NaN  2275.879083   NaN  NaN         NaN  NaN
#
# INDICATOR  OILPROD  YRLIFELOST
# 0              NaN         NaN
# ...

# %%
# Sample 

## Getting Started with Interactive Data Visualizations

# import pandas as pd
# import numpy as np

# %%
# co2 = pd.read_csv('data/co2.csv')
# co2.head()

# gm = pd.read_csv('data/gapminder.csv')
# gm.head()

# df_gm = gm[['Country', 'region']].drop_duplicates()

# df_w_regions = pd.merge(co2, df_gm, left_on='country', right_on='Country', how='inner')

# df_w_regions = df_w_regions.drop('Country', axis='columns')

# new_co2 = pd.melt(df_w_regions, id_vars=['country', 'region'])

# columns = ['country', 'region', 'year', 'co2']
# new_co2.columns = columns

# df_co2 = new_co2[new_co2['year'].astype('int64') > 1963]
# df_co2 = df_co2.sort_values(by=['country', 'year'])
# df_co2['year'] = df_co2['year'].astype('int64')
# df_co2.head()

# df_gdp = gm[['Country', 'Year', 'gdp']]
# df_gdp.columns = ['country', 'year', 'gdp']
# df_gdp.head()

# data = pd.merge(df_co2, df_gdp, on=['country', 'year'], how='left')

# data = data.dropna()
# data.head()

# np_co2 = np.array(data['co2'])
# np_gdp = np.array(data['gdp'])
# np.corrcoef(np_co2, np_gdp)

# from bokeh.io import curdoc, output_notebook
# from bokeh.plotting import figure, show
# from bokeh.models import HoverTool, ColumnDataSource, CategoricalColorMapper, Slider
# from bokeh.palettes import Spectral6
# from bokeh.layouts import widgetbox, row

# output_notebook()

# regions_list = data.region.unique().tolist()
# color_mapper = CategoricalColorMapper(factors=regions_list, palette=Spectral6)

# Make the ColumnDataSource: source


# source = ColumnDataSource(data={
#     'x': data.gdp[data['year'] == 1964],
#     'y': data.co2[data['year'] == 1964],
#     'country': data.country[data['year'] == 1964],
#     'region': data.region[data['year'] == 1964],
# })

# Save the minimum and maximum values of the gdp column: xmin, xmax

# xmin, xmax = min(data.gdp), max(data.gdp)

# Save the minimum and maximum values of the co2 column: ymin, ymax

# ymin, ymax = min(data.co2), max(data.co2)

# Create the figure: plot


# plot = figure(title='CO2 Emissions vs GDP in 1964', 
#               plot_height=600, plot_width=1000,
#               x_range=(xmin, xmax),
#               y_range=(ymin, ymax), y_axis_type='log')

# Add circle glyphs to the plot

# plot.circle(x='x', y='y', fill_alpha=0.8, source=source, legend='region',
#             color=dict(field='region', transform=color_mapper),
#             size=7)

# # Set the legend.location attribute of the plot
# plot.legend.location = 'bottom_right'

# # Set the x-axis label
# plot.xaxis.axis_label = 'Income Per Person'

# # Set the y-axis label
# plot.yaxis.axis_label = 'CO2 Emissions (tons per person)'

# show(plot)

# ### Adding a Slider to the Static Plot 

# slider = Slider(start=min(data.year), end=max(data.year), step=1,
# value=min(data.year), title='Year') 

# def update_plot(attr, old, new):
#     yr = slider.value
#     new_data = {
#      'x': data.gdp[data['year'] == yr], 
#      'y': data.co2[data['year'] == yr],
#      'country': data.country[data['year'] == yr],
#      'region': data.region[data['year'] == yr],
#     }
#     source.data = new_data
#     plot.title.text = 'CO2 Emissions vs GDP in %d' % yr 

# slider.on_change('value', update_plot)

# layout = row(widgetbox(slider), plot) 

# curdoc().add_root(layout) 

# ### Adding a Hover Tool 

# hover = HoverTool(tooltips=[('Country', '@country'), ('GDP', '@x'), ('CO2 Emission','@y')]) 

# plot.add_tools(hover) 

# !bokeh serve --show Getting_Started_with_Interactive_Data_Visualizations.ipynb

# ## Interactive Data Visualization with Plotly Express 

# import pandas as pd
# import plotly.express as px 

# co2 = pd.read_csv('data/co2.csv')
# gm = pd.read_csv('data/gapminder.csv')

# df_gm = gm[['Country', 'region']].drop_duplicates()
# df_w_regions = pd.merge(co2, df_gm, left_on='country', right_on='Country',how='inner')
# df_w_regions = df_w_regions.drop('Country', axis='columns')
# new_co2 = pd.melt(df_w_regions, id_vars=['country', 'region'])
# columns = ['country', 'region', 'year', 'co2']
# new_co2.columns = columns
# df_co2 = new_co2[new_co2['year'].astype('int64') > 1963]
# df_co2 = df_co2.sort_values(by=['country', 'year'])
# df_co2['year'] = df_co2['year'].astype('int64')
# df_gdp = gm[['Country', 'Year', 'gdp']]
# df_gdp.columns = ['country', 'year', 'gdp']
# data = pd.merge(df_co2, df_gdp, on=['country', 'year'], how='left') 
# data = data.dropna() 

# data.head() 


# xmin, xmax = min(data.gdp), max(data.gdp) 

# ymin, ymax = min(data.co2), max(data.co2) 

# fig = px.scatter(data, x="gdp", y="co2", animation_frame="year",
# animation_group="country", color="region", hover_name="country",
# facet_col="region", width=1579, height=400, log_x=True, size_max=45,
# range_x=[xmin,xmax], range_y=[ymin,ymax]) 


# fig.show()

# %% [markdown]
# ## Price Dataset

# %%
#df_price = pd.read_csv("Prices_E_All_Data/Prices_E_All_Data_upload.csv")
df_price.head(50)
# Out:
#     Area Code Area Code (M49)         Area  eu_member  Item Code  \
# 0           2            '004  Afghanistan          0        221
# 1           2            '004  Afghanistan          0        221
# 2           2            '004  Afghanistan          0        221
# 3           2            '004  Afghanistan          0        711
# 4           2            '004  Afghanistan          0        515
# 5           2            '004  Afghanistan          0        515
# 6           2            '004  Afghanistan          0        515
# 7           2            '004  Afghanistan          0        526
# 8           2            '004  Afghanistan          0        526
# 9           2            '004  Afghanistan          0        526
# 10          2            '004  Afghanistan          0         44
# 11          2            '004  Afghanistan          0         44
# 12          2            '004  Afghanistan          0         44
# ...

# %%
# selecting rows based on condition
df_price_eu = df_price.loc[df_price['eu_member'] == 1]

df_price_eu.head(50)
# Out:
#       Area Code Area Code (M49)     Area  eu_member  Item Code  \
# 3555         11            '040  Austria          1        515
# 3556         11            '040  Austria          1        515
# 3557         11            '040  Austria          1        515
# 3558         11            '040  Austria          1        515
# 3559         11            '040  Austria          1        515
# 3560         11            '040  Austria          1        515
# 3561         11            '040  Austria          1        515
# 3562         11            '040  Austria          1        515
# 3563         11            '040  Austria          1        515
# 3564         11            '040  Austria          1        515
# 3565         11            '040  Austria          1        515
# 3566         11            '040  Austria          1        515
# 3567         11            '040  Austria          1        515
# 3568         11            '040  Austria          1        515
# ...

# %%
# selecting rows based on condition
df_price_eu_ppi = df_price_eu.loc[df_price['Element'] == "Producer Price Index (2014-2016 = 100)"]

df_price_eu_ppi.head(50)
# Out:
#       Area Code Area Code (M49)     Area  eu_member  Item Code  \
# 3570         11            '040  Austria          1        515
# 3577         11            '040  Austria          1        526
# 3584         11            '040  Austria          1        367
# 3600         11            '040  Austria          1         44
# 3616         11            '040  Austria          1        176
# 3624         11            '040  Austria          1        181
# 3625         11            '040  Austria          1        420
# 3641         11            '040  Austria          1        358
# 3657         11            '040  Austria          1        426
# 3669         11            '040  Austria          1        393
# 3670         11            '040  Austria          1        108
# 3677         11            '040  Austria          1        531
# 3690         11            '040  Austria          1        401
# 3704         11            '040  Austria          1        397
# ...

# %%
# # selecting rows based on condition
# df_price_eu_ppi = df_price_eu.loc[df_price['Element'] == "Producer Price Index (2014-2016 = 100)"]

# df_price_eu_ppi.head(50)
# Out:
#       Area Code Area Code (M49)     Area  eu_member  Item Code  \
# 3570         11            '040  Austria          1        515
# 3577         11            '040  Austria          1        526
# 3584         11            '040  Austria          1        367
# 3600         11            '040  Austria          1         44
# 3616         11            '040  Austria          1        176
# 3624         11            '040  Austria          1        181
# 3625         11            '040  Austria          1        420
# 3641         11            '040  Austria          1        358
# 3657         11            '040  Austria          1        426
# 3669         11            '040  Austria          1        393
# 3670         11            '040  Austria          1        108
# 3677         11            '040  Austria          1        531
# 3690         11            '040  Austria          1        401
# 3704         11            '040  Austria          1        397
# ...

# %%
# selecting rows based on condition
df_price_eu_ppi_wh = df_price_eu_ppi.loc[df_price['Item'] == "Wheat"]

df_price_eu_ppi_wh.head(50)
# Out:
#        Area Code Area Code (M49)         Area  eu_member  Item Code  \
# 4317          11            '040      Austria          1         15
# 7214         255            '056      Belgium          1         15
# 11867         27            '100     Bulgaria          1         15
# 22389         98            '191      Croatia          1         15
# 22867         50            '196       Cyprus          1         15
# 23671        167            '203      Czechia          1         15
# 23960         54            '208      Denmark          1         15
# 27786         63            '233      Estonia          1         15
# 29703         67            '246      Finland          1         15
# 30375         68            '250       France          1         15
# 31908         79            '276      Germany          1         15
# 32807         84            '300       Greece          1         15
# 35816         97            '348      Hungary          1         15
# ...

# %%
df_price_eu_ppi_wh.to_csv("DATAOUTPUTS/df_price_eu_ppi_wh.csv", index = False)

# %%
areaList = ["Ireland", "Croatia"]

# Then filter these MRNs like-

df_price_eu_ppi_wh_Ire_Cro = df_price_eu_ppi_wh[df_price_eu_ppi_wh['Area'].isin(areaList)]

df_price_eu_ppi_wh_Ire_Cro
# Out:
#        Area Code Area Code (M49)     Area  eu_member  Item Code  \
# 22389         98            '191  Croatia          1         15
# 37930        104            '372  Ireland          1         15
#
#       Item Code (CPC)   Item  Element Code  \
# 22389           '0111  Wheat          5539
# 37930           '0111  Wheat          5539
#
#                                       Element  Months Code  ...   Y2012  \
# 22389  Producer Price Index (2014-2016 = 100)         7021  ...  127.50
# 37930  Producer Price Index (2014-2016 = 100)         7021  ...  142.18
#
#         Y2013   Y2014   Y2015  Y2016  Y2017   Y2018   Y2019   Y2020   Y2021
# 22389  102.58  110.09  105.96  83.95  94.75   99.02  101.58   96.01   90.51
# 37930  100.78  126.75   83.18  90.07  95.99  131.16   96.00  111.38  119.68
#
# [2 rows x 43 columns]

# %%
# df = df_price_eu_ppi_wh_Ire_Cro.dropna()
# df.head()

# %%
# df.drop(index='cow', columns='small')
# (columns=['B', 'C']) 

df_correl = df_price_eu_ppi_wh_Ire_Cro.drop(columns = ["Area Code", "Area Code (M49)", "eu_member", "Item Code", "Item Code (CPC)", "Element Code", "Months Code", "Item", "Element", "Months", "Unit", "Y1991"])
df_correl.head()
# Out:
#           Area  Y1992  Y1993  Y1994  Y1995   Y1996   Y1997  Y1998  Y1999  \
# 22389  Croatia   4.61  54.92  85.17  78.68  101.16  100.43  95.22  85.99
# 37930  Ireland  89.20  89.20  75.29  94.11   76.93   63.83  65.47  69.56
#
#        Y2000  ...   Y2012   Y2013   Y2014   Y2015  Y2016  Y2017   Y2018  \
# 22389  81.33  ...  127.50  102.58  110.09  105.96  83.95  94.75   99.02
# 37930  66.29  ...  142.18  100.78  126.75   83.18  90.07  95.99  131.16
#
#         Y2019   Y2020   Y2021
# 22389  101.58   96.01   90.51
# 37930   96.00  111.38  119.68
#
# [2 rows x 31 columns]

# %%
# df.drop(index='cow', columns='small')
# (columns=['B', 'C']) 
df_price_eu_ppi_wh
df_price_eu_ppi_wh_sm = df_price_eu_ppi_wh.drop(columns = ["Area Code", "Area Code (M49)", "eu_member", "Item Code", "Item Code (CPC)", "Element Code", "Months Code", "Item", "Element", "Months", "Unit", "Y1991"])
df_price_eu_ppi_wh_sm.head()
# Out:
#            Area   Y1992   Y1993   Y1994  Y1995   Y1996   Y1997  Y1998  Y1999  \
# 4317    Austria  186.64  187.32  173.96  87.94   99.32   85.86  85.18  84.78
# 7214    Belgium     NaN     NaN     NaN    NaN     NaN     NaN    NaN    NaN
# 11867  Bulgaria     NaN     NaN     NaN    NaN     NaN     NaN  45.36  48.66
# 22389   Croatia    4.61   54.92   85.17  78.68  101.16  100.43  95.22  85.99
# 22867    Cyprus   81.50   81.50   85.26  88.40   89.02   89.02  88.40  91.53
#
#        Y2000  ...   Y2012   Y2013   Y2014   Y2015   Y2016   Y2017   Y2018  \
# 4317   85.69  ...  163.57  114.73  104.65  106.20   89.15  112.40  119.38
# 7214   73.31  ...  148.00  131.71  109.25  102.34   88.41   93.70  110.42
# 11867  65.44  ...  135.58  105.71  105.38  102.34   92.29  100.95  102.25
# 22389  81.33  ...  127.50  102.58  110.09  105.96   83.95   94.75   99.02
# 22867  91.53  ...   93.15   89.49   94.62   90.95  114.43   79.95   95.46
#
#         Y2019   Y2020   Y2021
# ...

# %%
df_price_eu_ppi_wh_sm = df_price_eu_ppi_wh.drop(columns = ["Area Code", "Area Code (M49)", "eu_member", "Item Code", "Item Code (CPC)", "Element Code", "Months Code", "Item", "Element", "Months", "Unit", "Y1991"])
df_price_eu_ppi_wh_sm.head()
# Out:
#            Area   Y1992   Y1993   Y1994  Y1995   Y1996   Y1997  Y1998  Y1999  \
# 4317    Austria  186.64  187.32  173.96  87.94   99.32   85.86  85.18  84.78
# 7214    Belgium     NaN     NaN     NaN    NaN     NaN     NaN    NaN    NaN
# 11867  Bulgaria     NaN     NaN     NaN    NaN     NaN     NaN  45.36  48.66
# 22389   Croatia    4.61   54.92   85.17  78.68  101.16  100.43  95.22  85.99
# 22867    Cyprus   81.50   81.50   85.26  88.40   89.02   89.02  88.40  91.53
#
#        Y2000  ...   Y2012   Y2013   Y2014   Y2015   Y2016   Y2017   Y2018  \
# 4317   85.69  ...  163.57  114.73  104.65  106.20   89.15  112.40  119.38
# 7214   73.31  ...  148.00  131.71  109.25  102.34   88.41   93.70  110.42
# 11867  65.44  ...  135.58  105.71  105.38  102.34   92.29  100.95  102.25
# 22389  81.33  ...  127.50  102.58  110.09  105.96   83.95   94.75   99.02
# 22867  91.53  ...   93.15   89.49   94.62   90.95  114.43   79.95   95.46
#
#         Y2019   Y2020   Y2021
# ...

# %%
df_price_eu_ppi_wh_sm.to_csv("df_price_eu_ppi_wh_sm.csv", index = False)

# %%
# df_price_eu_ppi_wh_Ire_Cro.to_csv("DATAOUTPUTS/df_price_eu_ppi_wh_Ire_Cro.csv")

# %%
df_correl.to_csv("DATAOUTPUTS/df_price_eu_ppi_wh_Ire_Cro_sm.csv", index = False)

# %%
df_correl(index == "Area")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [137], in <cell line: 1>()
# ----> 1 df_correl(index == "Area")
#
# NameError: name 'index' is not defined

# %%
# df_price_eu_ppi_wh_sm_trans = df_price_eu_ppi_wh_sm.reset_index().transpose()
# df_price_eu_ppi_wh_sm_trans.head()

# %%
# df_price_eu_ppi_wh_sm_melt = df_price_eu_ppi_wh_sm.reset_index().melt()
# df_price_eu_ppi_wh_sm_melt.head()
# Out:
#   variable  value
# 0    index   4317
# 1    index   7214
# 2    index  11867
# 3    index  22389
# 4    index  22867

# %%
# 
# Assign row as column headers

# ########################## Only do this once, your you'll keep losing rows. 
# df_price_eu_ppi_wh_sm_trans2 = df_price_eu_ppi_wh_sm_trans.columns = df_price_eu_ppi_wh_sm_trans.iloc[0]
# df_price_eu_ppi_wh_sm_trans2.head()
# Out:
# index
# 4317      4317
# 7214      7214
# 11867    11867
# 22389    22389
# 22867    22867
# Name: index, dtype: object

# %%
# import matplotlib.pyplot as plt

# f = plt.figure(figsize=(19, 15))
# plt.matshow(df_correl.corr(), fignum=f.number)
# plt.xticks(range(df_correl.select_dtypes(['number']).shape[1]), df_correl.select_dtypes(['number']).columns, fontsize=14, rotation=45)
# plt.yticks(range(df_correl.select_dtypes(['number']).shape[1]), df_correl.select_dtypes(['number']).columns, fontsize=14)
# cb = plt.colorbar()
# cb.ax.tick_params(labelsize=14)
# plt.title('Correlation Matrix', fontsize=16);

# %%
df_correl_trans = df_correl.transpose()

# %%
df_correl_trans.head()
# Out:
#          22389    37930
# Area   Croatia  Ireland
# Y1992     4.61     89.2
# Y1993    54.92     89.2
# Y1994    85.17    75.29
# Y1995    78.68    94.11

# %%
df_correl_trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, Area to Y2021
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   22389   31 non-null     object
#  1   37930   31 non-null     object
# dtypes: object(2)
# memory usage: 1.8+ KB

# %%
# Assign row as column headers
# df_correl_trans.columns = df_correl_trans.iloc[0]

# # Using DataFrame.rename()
# df_correl_trans2 = df_correl_trans.rename(columns=df_correl_trans.iloc[1])

# # Convert row to header and remove the row
# df_correl_trans2 = df_correl_trans.rename(columns=df_correl_trans.iloc[0]).loc[1:]

# # Using DataFrame.rename() to convert row to column header
# df_correl_trans.rename(columns=df_correl_trans.iloc[1], inplace = True)

# # Using DataFrame.values[]
# header_row = df_correl_trans.iloc[0]
# df_correl_trans2 = pd.DataFrame(df_correl_trans.values[1:], columns=header_row)

# %% [markdown]
# # CLEAN START

# %%
# ALL GDP DF COPIED
df_all_gdp = df_gdp

# %%
# IMPORT LOOKUP TABLES
df_country_lookup = pd.read_csv("DATA/Country_lookups.csv")
df_country_lookup
# Out:
#                    Lookup Area  Lookup M49 Lookup iso
# 0                  Afghanistan           4        AFG
# 1                Åland Islands         248        ALA
# 2                      Albania           8        ALB
# 3                      Algeria          12        DZA
# 4               American Samoa          16        ASM
# ..                         ...         ...        ...
# 244  Wallis and Futuna Islands         876        WLF
# 245             Western Sahara         732        ESH
# 246                      Yemen         887        YEM
# 247                     Zambia         894        ZMB
# 248                   Zimbabwe         716        ZWE
#
# [249 rows x 3 columns]

# %%
df_all_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 704 entries, 0 to 703
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    704 non-null    object
#  1   INDICATOR   704 non-null    object
#  2   SUBJECT     704 non-null    object
#  3   MEASURE     704 non-null    object
#  4   FREQUENCY   704 non-null    object
#  5   TIME        704 non-null    int64
#  6   GDP         704 non-null    float64
#  7   Flag Codes  47 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 44.1+ KB

# %%
df_all_gdp_isolookup = pd.merge(left=df_all_gdp, right=df_country_lookup, how='left', left_on='LOCATION', right_on='Lookup iso')
df_all_gdp_isolookup
# Out:
#     LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME           GDP  \
# 0        AUT       GDP     TOT  USD_CAP         A  2000  29380.031110
# 1        AUT       GDP     TOT  USD_CAP         A  2001  29707.462264
# 2        AUT       GDP     TOT  USD_CAP         A  2002  31178.051444
# 3        AUT       GDP     TOT  USD_CAP         A  2003  32158.225907
# 4        AUT       GDP     TOT  USD_CAP         A  2004  33784.432645
# ..       ...       ...     ...      ...       ...   ...           ...
# 699      ROU       GDP     TOT  USD_CAP         A  2017  27135.977062
# 700      ROU       GDP     TOT  USD_CAP         A  2018  29337.903177
# 701      ROU       GDP     TOT  USD_CAP         A  2019  32909.566163
# 702      ROU       GDP     TOT  USD_CAP         A  2020  33080.128126
# 703      ROU       GDP     TOT  USD_CAP         A  2021  35946.765464
#
#     Flag Codes Lookup Area  Lookup M49 Lookup iso
# 0          NaN     Austria        40.0        AUT
# ...

# %%
df_all_gdp_isolookup.rename(columns = {'Value': 'GDP'}, inplace = True)
df_all_gdp_isolookup.head(5)
# Out:
#   LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME           GDP  \
# 0      AUT       GDP     TOT  USD_CAP         A  2000  29380.031110
# 1      AUT       GDP     TOT  USD_CAP         A  2001  29707.462264
# 2      AUT       GDP     TOT  USD_CAP         A  2002  31178.051444
# 3      AUT       GDP     TOT  USD_CAP         A  2003  32158.225907
# 4      AUT       GDP     TOT  USD_CAP         A  2004  33784.432645
#
#   Flag Codes Lookup Area  Lookup M49 Lookup iso
# 0        NaN     Austria        40.0        AUT
# 1        NaN     Austria        40.0        AUT
# 2        NaN     Austria        40.0        AUT
# 3        NaN     Austria        40.0        AUT
# 4        NaN     Austria        40.0        AUT

# %%
df_all_gdp_isolookup['TIME'].unique()
# print(df['Courses'].unique())
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021],
#       dtype=int64)

# %%
df_all_gdp_isolookup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 704 entries, 0 to 703
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LOCATION     704 non-null    object
#  1   INDICATOR    704 non-null    object
#  2   SUBJECT      704 non-null    object
#  3   MEASURE      704 non-null    object
#  4   FREQUENCY    704 non-null    object
#  5   TIME         704 non-null    int64
#  6   GDP          704 non-null    float64
#  7   Flag Codes   47 non-null     object
#  8   Lookup Area  682 non-null    object
#  9   Lookup M49   682 non-null    float64
#  10  Lookup iso   682 non-null    object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 66.0+ KB

# %%
wheat_mask = (df_price.Item == "Wheat") & (df_price.Element == "Producer Price Index (2014-2016 = 100)")
df_price_wheat_ppi = df_price[wheat_mask]

# %%
df_price_wheat_ppi.head(2)
# df_price_wheat_ppi.melt()
# df_price_wheat_ppi.transpose()
# Out:
#       Area Code Area Code (M49)         Area  eu_member  Item Code  \
# 94            2            '004  Afghanistan          0         15
# 1042          3            '008      Albania          0         15
#
#      Item Code (CPC)   Item  Element Code  \
# 94             '0111  Wheat          5539
# 1042           '0111  Wheat          5539
#
#                                      Element  Months Code  ...   Y2012  \
# 94    Producer Price Index (2014-2016 = 100)         7021  ...   26.70
# 1042  Producer Price Index (2014-2016 = 100)         7021  ...  103.67
#
#        Y2013   Y2014   Y2015   Y2016   Y2017   Y2018  Y2019  Y2020  Y2021
# 94     35.74   72.39  111.10  116.51  112.41  111.54  96.20  86.08  62.99
# 1042  114.30  101.01  101.01   97.97   87.65   84.39  83.74  85.10  86.46
#
# [2 rows x 43 columns]

# %%
df_price_wheat_ppi.columns
# Out:
# Index(['Area Code', 'Area Code (M49)', 'Area', 'eu_member', 'Item Code',
#        'Item Code (CPC)', 'Item', 'Element Code', 'Element', 'Months Code',
#        'Months', 'Unit', 'Y1991', 'Y1992', 'Y1993', 'Y1994', 'Y1995', 'Y1996',
#        'Y1997', 'Y1998', 'Y1999', 'Y2000', 'Y2001', 'Y2002', 'Y2003', 'Y2004',
#        'Y2005', 'Y2006', 'Y2007', 'Y2008', 'Y2009', 'Y2010', 'Y2011', 'Y2012',
#        'Y2013', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018', 'Y2019', 'Y2020',
#        'Y2021'],
#       dtype='object')

# %%
# df_price_wheat_ppi.info()

# %%
df_price_wheat_ppi_melted = df_price_wheat_ppi.melt(id_vars=['Area Code', 'Area Code (M49)', 'Area', 'eu_member', 'Item Code',
       'Item Code (CPC)', 'Item', 'Element Code', 'Element', 'Months Code',
       'Months', 'Unit'], value_vars=['Y1991', 'Y1992', 'Y1993', 'Y1994', 'Y1995', 'Y1996',
       'Y1997', 'Y1998', 'Y1999', 'Y2000', 'Y2001', 'Y2002', 'Y2003', 'Y2004',
       'Y2005', 'Y2006', 'Y2007', 'Y2008', 'Y2009', 'Y2010', 'Y2011', 'Y2012',
       'Y2013', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018', 'Y2019', 'Y2020',
       'Y2021'], var_name="YEAR", value_name="wheat_PPI")

# %%
df_price_wheat_ppi_melted.columns
# Out:
# Index(['Area Code', 'Area Code (M49)', 'Area', 'eu_member', 'Item Code',
#        'Item Code (CPC)', 'Item', 'Element Code', 'Element', 'Months Code',
#        'Months', 'Unit', 'YEAR', 'wheat_PPI'],
#       dtype='object')

# %%
df_price_wheat_ppi_melted.head()
# Out:
#    Area Code Area Code (M49)         Area  eu_member  Item Code  \
# 0          2            '004  Afghanistan          0         15
# 1          3            '008      Albania          0         15
# 2          4            '012      Algeria          0         15
# 3          9            '032    Argentina          0         15
# 4          1            '051      Armenia          0         15
#
#   Item Code (CPC)   Item  Element Code  \
# 0           '0111  Wheat          5539
# 1           '0111  Wheat          5539
# 2           '0111  Wheat          5539
# 3           '0111  Wheat          5539
# 4           '0111  Wheat          5539
#
#                                   Element  Months Code        Months Unit  \
# 0  Producer Price Index (2014-2016 = 100)         7021  Annual value  NaN
# 1  Producer Price Index (2014-2016 = 100)         7021  Annual value  NaN
# 2  Producer Price Index (2014-2016 = 100)         7021  Annual value  NaN
# ...

# %%
# SPOT CHECK DATA
wheat_ppi_spot_check_mask = (df_price_wheat_ppi.Area == "Armenia")
df_spot_check = df_price_wheat_ppi[wheat_ppi_spot_check_mask]
df_spot_check[['Area', 'Y1991']]
# Out:
#          Area  Y1991
# 3150  Armenia    NaN

# %%
# df_price_wheat_ppi_melted.to_csv("DATAOUTPUTS/df_price_wheat_ppi_melted.csv", index = False)

# %%
# MAKE NEW COLUMN YEAR_INT, WITH int64 BY CHANGING YEAR
df_price_wheat_ppi_melted['YEAR_INT'] = df_price_wheat_ppi_melted['YEAR'].str.slice(1,)

# %%
df_price_wheat_ppi_melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3317 entries, 0 to 3316
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area Code        3317 non-null   int64
#  1   Area Code (M49)  3317 non-null   object
#  2   Area             3317 non-null   object
#  3   eu_member        3317 non-null   int64
#  4   Item Code        3317 non-null   int64
#  5   Item Code (CPC)  3317 non-null   object
#  6   Item             3317 non-null   object
#  7   Element Code     3317 non-null   int64
#  8   Element          3317 non-null   object
#  9   Months Code      3317 non-null   int64
#  10  Months           3317 non-null   object
#  11  Unit             0 non-null      object
#  12  YEAR             3317 non-null   object
#  13  wheat_PPI        3091 non-null   float64
#  14  YEAR_INT         3317 non-null   object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 388.8+ KB

# %%
df_price_wheat_ppi_melted['YEAR_INT'] = df_price_wheat_ppi_melted['YEAR_INT'].astype(str).astype(int)

# %%
df_price_wheat_ppi_melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3317 entries, 0 to 3316
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area Code        3317 non-null   int64
#  1   Area Code (M49)  3317 non-null   object
#  2   Area             3317 non-null   object
#  3   eu_member        3317 non-null   int64
#  4   Item Code        3317 non-null   int64
#  5   Item Code (CPC)  3317 non-null   object
#  6   Item             3317 non-null   object
#  7   Element Code     3317 non-null   int64
#  8   Element          3317 non-null   object
#  9   Months Code      3317 non-null   int64
#  10  Months           3317 non-null   object
#  11  Unit             0 non-null      object
#  12  YEAR             3317 non-null   object
#  13  wheat_PPI        3091 non-null   float64
#  14  YEAR_INT         3317 non-null   int32
# dtypes: float64(1), int32(1), int64(5), object(8)
# memory usage: 375.9+ KB

# %%
# MERGE

# %%
df_all_gdp_isolookup.head(5)
# Out:
#   LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME           GDP  \
# 0      AUT       GDP     TOT  USD_CAP         A  2000  29380.031110
# 1      AUT       GDP     TOT  USD_CAP         A  2001  29707.462264
# 2      AUT       GDP     TOT  USD_CAP         A  2002  31178.051444
# 3      AUT       GDP     TOT  USD_CAP         A  2003  32158.225907
# 4      AUT       GDP     TOT  USD_CAP         A  2004  33784.432645
#
#   Flag Codes Lookup Area  Lookup M49 Lookup iso
# 0        NaN     Austria        40.0        AUT
# 1        NaN     Austria        40.0        AUT
# 2        NaN     Austria        40.0        AUT
# 3        NaN     Austria        40.0        AUT
# 4        NaN     Austria        40.0        AUT

# %%
df_price_wheat_ppi_melted.head(5)
# Out:
#    Area Code Area Code (M49)         Area  eu_member  Item Code  \
# 0          2            '004  Afghanistan          0         15
# 1          3            '008      Albania          0         15
# 2          4            '012      Algeria          0         15
# 3          9            '032    Argentina          0         15
# 4          1            '051      Armenia          0         15
#
#   Item Code (CPC)   Item  Element Code  \
# 0           '0111  Wheat          5539
# 1           '0111  Wheat          5539
# 2           '0111  Wheat          5539
# 3           '0111  Wheat          5539
# 4           '0111  Wheat          5539
#
#                                   Element  Months Code        Months Unit  \
# 0  Producer Price Index (2014-2016 = 100)         7021  Annual value  NaN
# 1  Producer Price Index (2014-2016 = 100)         7021  Annual value  NaN
# 2  Producer Price Index (2014-2016 = 100)         7021  Annual value  NaN
# ...

# %%
### BROKEN - DONT WANT A LEFT JOIN
# df_all_gdp_ppi = pd.merge(left=df_all_gdp_isolookup, right=df_price_wheat_ppi_melted, how='left', left_on='Lookup Area', right_on='Area')
# df_all_gdp_ppi

# %%
df_all_gdp_ppi =  df_all_gdp_isolookup.merge(df_price_wheat_ppi_melted, how='inner', left_on=['Lookup Area', 'TIME'], right_on=['Area', 'YEAR_INT'])
df_spot_check_all = df_all_gdp_ppi[['LOCATION', 'Area', 'eu_member', 'GDP', 'wheat_PPI', 'TIME', 'YEAR', 'YEAR_INT' ]]

# %%
df_spot_check_all
# Out:
#     LOCATION     Area  eu_member           GDP  wheat_PPI  TIME   YEAR  \
# 0        AUT  Austria          1  29380.031110      85.69  2000  Y2000
# 1        AUT  Austria          1  29707.462264      82.98  2001  Y2001
# 2        AUT  Austria          1  31178.051444      75.97  2002  Y2002
# 3        AUT  Austria          1  32158.225907      83.72  2003  Y2003
# 4        AUT  Austria          1  33784.432645      68.22  2004  Y2004
# ..       ...      ...        ...           ...        ...   ...    ...
# 677      ROU  Romania          1  27135.977062      91.55  2017  Y2017
# 678      ROU  Romania          1  29337.903177      95.77  2018  Y2018
# 679      ROU  Romania          1  32909.566163     102.82  2019  Y2019
# 680      ROU  Romania          1  33080.128126     111.27  2020  Y2020
# 681      ROU  Romania          1  35946.765464     119.72  2021  Y2021
#
#      YEAR_INT
# 0        2000
# 1        2001
# 2        2002
# 3        2003
# 4        2004
# ..        ...
# ...

# %%
print(df_price_wheat_ppi.columns)
# Out:
# Index(['Area Code', 'Area Code (M49)', 'Area', 'eu_member', 'Item Code',
#        'Item Code (CPC)', 'Item', 'Element Code', 'Element', 'Months Code',
#        'Months', 'Unit', 'Y1991', 'Y1992', 'Y1993', 'Y1994', 'Y1995', 'Y1996',
#        'Y1997', 'Y1998', 'Y1999', 'Y2000', 'Y2001', 'Y2002', 'Y2003', 'Y2004',
#        'Y2005', 'Y2006', 'Y2007', 'Y2008', 'Y2009', 'Y2010', 'Y2011', 'Y2012',
#        'Y2013', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018', 'Y2019', 'Y2020',
#        'Y2021'],
#       dtype='object')

# %%
wheat_ppi_spot_check_mask = (df_price_wheat_ppi.Area == "Armenia")
df_spot_check = df_price_wheat_ppi[wheat_ppi_spot_check_mask]
df_spot_check[['Area', 'Y1991', 'Y1992', 'Y1993', 'Y1994', 'Y1995', 'Y1996',
       'Y1997', 'Y1998', 'Y1999', 'Y2000', 'Y2001', 'Y2002', 'Y2003', 'Y2004',
       'Y2005', 'Y2006', 'Y2007', 'Y2008', 'Y2009', 'Y2010', 'Y2011', 'Y2012',
       'Y2013', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018', 'Y2019', 'Y2020',
       'Y2021']]
# Out:
#          Area  Y1991  Y1992  Y1993  Y1994  Y1995  Y1996  Y1997  Y1998  Y1999  \
# 3150  Armenia    NaN    NaN    NaN    NaN    NaN    NaN   89.4  83.91  76.79
#
#       ...   Y2012   Y2013   Y2014  Y2015  Y2016  Y2017  Y2018  Y2019   Y2020  \
# 3150  ...  127.88  130.99  114.94   95.3  89.77  91.97  91.63  101.5  104.97
#
#        Y2021
# 3150  106.61
#
# [1 rows x 32 columns]

# %%
all_spot_check_mask = (df_spot_check_all.Area == "Armenia")
all_spot_check_df = df_spot_check_all[all_spot_check_mask]
print(all_spot_check_df[['Area', 'TIME', 'wheat_PPI' ]])
# Out:
# Empty DataFrame
# Columns: [Area, TIME, wheat_PPI]
# Index: []

# %%
print(df_spot_check_all['eu_member'].unique())
# Out:
# [1 0]

# %%
print(df_all_gdp_ppi["Lookup Area"].unique())
# Out:
# ['Austria' 'Belgium' 'Canada' 'Czechia' 'Denmark' 'Finland' 'France'
#  'Germany' 'Greece' 'Hungary' 'Ireland' 'Italy' 'Japan' 'Luxembourg'
#  'Netherlands' 'Poland' 'Portugal' 'Slovakia' 'Spain' 'Sweden'
#  'United Kingdom of Great Britain and Northern Ireland'
#  'United States of America' 'Estonia' 'Slovenia' 'Latvia' 'Lithuania'
#  'Bulgaria' 'Croatia' 'Cyprus' 'Malta' 'Romania']

# %%
# df_all_gdp_ppi

# %%
# FINAL DF
df_all_gdp_ppi.to_csv("DATAOUTPUTS/df_all_gdp_ppi.csv", index=False)

# %%
df_all_gdp_ppi[['LOCATION', 'Area', 'eu_member', 'GDP', 'wheat_PPI', 'TIME', 'YEAR', 'YEAR_INT' ]]
# Out:
#     LOCATION     Area  eu_member           GDP  wheat_PPI  TIME   YEAR  \
# 0        AUT  Austria          1  29380.031110      85.69  2000  Y2000
# 1        AUT  Austria          1  29707.462264      82.98  2001  Y2001
# 2        AUT  Austria          1  31178.051444      75.97  2002  Y2002
# 3        AUT  Austria          1  32158.225907      83.72  2003  Y2003
# 4        AUT  Austria          1  33784.432645      68.22  2004  Y2004
# ..       ...      ...        ...           ...        ...   ...    ...
# 677      ROU  Romania          1  27135.977062      91.55  2017  Y2017
# 678      ROU  Romania          1  29337.903177      95.77  2018  Y2018
# 679      ROU  Romania          1  32909.566163     102.82  2019  Y2019
# 680      ROU  Romania          1  33080.128126     111.27  2020  Y2020
# 681      ROU  Romania          1  35946.765464     119.72  2021  Y2021
#
#      YEAR_INT
# 0        2000
# 1        2001
# 2        2002
# 3        2003
# 4        2004
# ..        ...
# ...
