# %%
## Go back to the brief, make sure everything is ticked off
## It's why WHY that's important. Why by expirimentation and/or referencing. 
# Why boxplot, why colours, why titles, etc. etc. in the report (for David, 200-300 words) in the markdown for sam. Sam only read the notebook I think.  
## There's a template for CA3 
 # Intro, main body, conclusion 
# Resources on Student Success 
# See Research papers on David's Moodle page as samples for structure
# Go back to the feedback form CA1

# %%
# Fix Github to Public

# %%
#  Reading - what impacts the price of wheat 
# https://www.ers.usda.gov/webdocs/publications/47264/51088_tb1878b.pdf?v=0 
## https://www.economicshelp.org/blog/168151/economics/factors-determining-the-price-of-wheat/#:~:text=The%20price%20of%20wheat%20is,climate%20factors%20affecting%20the%20supply.

# %%
import pandas as pd
import matplotlib as mpl
import numpy as np

# %%
# Import all economic datasets


df1 = pd.read_csv("DATA/DP_LIVE_06012023190448991.csv")
df2 = pd.read_csv("DATA/DP_LIVE_06012023190508679.csv")
df3 = pd.read_csv("DATA/DP_LIVE_06012023190521038.csv")
df4 = pd.read_csv("DATA/DP_LIVE_06012023190621335.csv")
df5 = pd.read_csv("DATA/DP_LIVE_06012023190631007.csv")
df6 = pd.read_csv("DATA/DP_LIVE_06012023190759570.csv")
df7 = pd.read_csv("DATA/DP_LIVE_06012023190909741.csv")
df8 = pd.read_csv("DATA/DP_LIVE_06012023191011288.csv")
df9 = pd.read_csv("DATA/DP_LIVE_06012023191646976.csv")
df10 = pd.read_csv("DATA/DP_LIVE_06012023192018179.csv")
df11 = pd.read_csv("DATA/DP_LIVE_06012023192105335.csv")
df12 = pd.read_csv("DATA/DP_LIVE_06012023214944235.csv")
df13 = pd.read_csv("DATA/DP_LIVE_06012023215221798.csv")
df14 = pd.read_csv("DATA/PPP-EU.csv")

# %%
# Monthly = df1 (CCI), df2 (CLI) , df3 (CLI)

# %%
# Quarterly = df11 (HHI)

# %%
# Annually = df4 (GDP), df5 (GDP), df6 (GFCFSector), df7 (cropyield), df8, (aggsupp), df9 (exch), df10 (GNI), df11, (grossAJD), df 12 (YRLIFELOST), df13 (oilprod), df14 (ppp)

# %%
df11.tail(50)
# Out:
#      LOCATION INDICATOR SUBJECT      MEASURE FREQUENCY     TIME  Value  \
# 3021     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2010-Q1   0.20
# 3022     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2010-Q2   0.68
# 3023     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2010-Q3   0.52
# 3024     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2010-Q4   0.12
# 3025     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2011-Q1   0.36
# 3026     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2011-Q2   0.02
# 3027     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2011-Q3   0.13
# 3028     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2011-Q4  -0.09
# 3029     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2012-Q1   0.74
# 3030     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2012-Q2   0.14
# 3031     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2012-Q3  -0.21
# 3032     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2012-Q4   0.92
# 3033     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2013-Q1  -0.64
# 3034     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2013-Q2   0.65
# 3035     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2013-Q3   0.38
# 3036     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2013-Q4   0.05
# 3037     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2014-Q1   0.40
# 3038     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2014-Q2   0.62
# 3039     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2014-Q3   0.73
# 3040     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2014-Q4   0.84
# 3041     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2015-Q1   0.87
# 3042     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2015-Q2   0.28
# 3043     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2015-Q3   0.51
# 3044     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2015-Q4   0.35
# 3045     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2016-Q1   0.61
# 3046     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2016-Q2   0.08
# 3047     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2016-Q3   0.22
# 3048     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2016-Q4   0.46
# 3049     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2017-Q1   0.38
# 3050     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2017-Q2   0.89
# 3051     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2017-Q3   0.49
# 3052     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2017-Q4   0.39
# 3053     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2018-Q1   0.59
# 3054     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2018-Q2   0.31
# 3055     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2018-Q3   0.43
# 3056     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2018-Q4   0.56
# 3057     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2019-Q1   0.85
# 3058     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2019-Q2   0.28
# 3059     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2019-Q3   0.48
# 3060     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2019-Q4   0.36
# 3061     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2020-Q1   0.24
# 3062     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2020-Q2   3.72
# 3063     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2020-Q3  -0.22
# 3064     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2020-Q4  -1.06
# 3065     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2021-Q1   5.09
# 3066     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2021-Q2  -3.51
# 3067     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2021-Q3  -0.03
# 3068     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2021-Q4  -0.29
# 3069     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2022-Q1  -1.15
# 3070     OECD      HHDI   GROSS  PC_CHGPPCAP         Q  2022-Q2  -0.51
#
#      Flag Codes
# 3021        NaN
# 3022        NaN
# 3023        NaN
# 3024        NaN
# 3025        NaN
# 3026        NaN
# 3027        NaN
# 3028        NaN
# 3029        NaN
# 3030        NaN
# 3031        NaN
# 3032        NaN
# 3033        NaN
# 3034        NaN
# 3035        NaN
# 3036        NaN
# 3037        NaN
# 3038        NaN
# 3039        NaN
# 3040        NaN
# 3041        NaN
# 3042        NaN
# 3043        NaN
# 3044        NaN
# 3045        NaN
# 3046        NaN
# 3047        NaN
# 3048        NaN
# 3049        NaN
# 3050        NaN
# 3051        NaN
# 3052        NaN
# 3053        NaN
# 3054        NaN
# 3055        NaN
# 3056        NaN
# 3057        NaN
# 3058        NaN
# 3059        NaN
# 3060        NaN
# 3061        NaN
# 3062        NaN
# 3063        NaN
# 3064        NaN
# 3065        NaN
# 3066        NaN
# 3067        NaN
# 3068        NaN
# 3069        NaN
# 3070        NaN

# %%
# Combine to make master economic set. As all in the same format, we can stack the DataFrames on top of each other
df_econ = pd.concat([df4, df5, df6, df7, df8, df9, df10, df12, df13], axis=0)

# %%
df_econ.describe()
# Out:
#                TIME         Value
# count  33379.000000  3.337900e+04
# mean    2008.754247  1.401094e+04
# std       10.735205  6.024846e+04
# min     1986.000000 -2.635270e+05
# 25%     2000.000000  2.034000e+00
# 50%     2009.000000  7.361200e+01
# 75%     2017.000000  4.776456e+03
# max     2030.000000  1.312195e+06

# %%
df_econ.head(50)
# Out:
#    LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME          Value  \
# 0       AUT       GDP     TOT  USD_CAP         A  2018   56956.110562
# 1       AUT       GDP     TOT  USD_CAP         A  2019   59719.331647
# 2       AUT       GDP     TOT  USD_CAP         A  2020   57253.300563
# 3       AUT       GDP     TOT  USD_CAP         A  2021   59976.264665
# 4       BEL       GDP     TOT  USD_CAP         A  2018   52530.841510
# 5       BEL       GDP     TOT  USD_CAP         A  2019   55800.825988
# 6       BEL       GDP     TOT  USD_CAP         A  2020   54539.032525
# 7       BEL       GDP     TOT  USD_CAP         A  2021   58816.266983
# 8       CAN       GDP     TOT  USD_CAP         A  2018   49992.811418
# 9       CAN       GDP     TOT  USD_CAP         A  2019   49832.297981
# 10      CAN       GDP     TOT  USD_CAP         A  2020   47228.372488
# 11      CAN       GDP     TOT  USD_CAP         A  2021   53074.088264
# 12      CZE       GDP     TOT  USD_CAP         A  2018   41157.370409
# 13      CZE       GDP     TOT  USD_CAP         A  2019   44223.088155
# 14      CZE       GDP     TOT  USD_CAP         A  2020   42813.741340
# 15      CZE       GDP     TOT  USD_CAP         A  2021   44799.547333
# 16      DNK       GDP     TOT  USD_CAP         A  2018   57479.350221
# 17      DNK       GDP     TOT  USD_CAP         A  2019   59883.836280
# 18      DNK       GDP     TOT  USD_CAP         A  2020   60840.940164
# 19      DNK       GDP     TOT  USD_CAP         A  2021   64897.769113
# 20      FIN       GDP     TOT  USD_CAP         A  2018   49573.255773
# 21      FIN       GDP     TOT  USD_CAP         A  2019   51811.356163
# 22      FIN       GDP     TOT  USD_CAP         A  2020   52290.401497
# 23      FIN       GDP     TOT  USD_CAP         A  2021   54856.553847
# 24      FRA       GDP     TOT  USD_CAP         A  2018   46336.933985
# 25      FRA       GDP     TOT  USD_CAP         A  2019   50221.997111
# 26      FRA       GDP     TOT  USD_CAP         A  2020   47823.919578
# 27      FRA       GDP     TOT  USD_CAP         A  2021   50998.933198
# 28      DEU       GDP     TOT  USD_CAP         A  2018   55195.722049
# 29      DEU       GDP     TOT  USD_CAP         A  2019   57397.204591
# 30      DEU       GDP     TOT  USD_CAP         A  2020   56476.934309
# 31      DEU       GDP     TOT  USD_CAP         A  2021   58784.138861
# 32      GRC       GDP     TOT  USD_CAP         A  2018   29617.499309
# 33      GRC       GDP     TOT  USD_CAP         A  2019   31155.847016
# 34      GRC       GDP     TOT  USD_CAP         A  2020   28413.787339
# 35      GRC       GDP     TOT  USD_CAP         A  2021   31177.251307
# 36      HUN       GDP     TOT  USD_CAP         A  2018   31908.661917
# 37      HUN       GDP     TOT  USD_CAP         A  2019   34638.671964
# 38      HUN       GDP     TOT  USD_CAP         A  2020   34156.840044
# 39      HUN       GDP     TOT  USD_CAP         A  2021   36677.803167
# 40      IRL       GDP     TOT  USD_CAP         A  2018   84824.352993
# 41      IRL       GDP     TOT  USD_CAP         A  2019   89846.272208
# 42      IRL       GDP     TOT  USD_CAP         A  2020   94028.901163
# 43      IRL       GDP     TOT  USD_CAP         A  2021  106852.122229
# 44      ITA       GDP     TOT  USD_CAP         A  2018   43427.663143
# 45      ITA       GDP     TOT  USD_CAP         A  2019   45799.526931
# 46      ITA       GDP     TOT  USD_CAP         A  2020   43129.896677
# 47      ITA       GDP     TOT  USD_CAP         A  2021   46546.248219
# 48      JPN       GDP     TOT  USD_CAP         A  2018   42239.050068
# 49      JPN       GDP     TOT  USD_CAP         A  2019   42465.480080
#
#    Flag Codes
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6           P
# 7           P
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25          P
# 26          P
# 27          P
# 28        NaN
# 29          P
# 30          P
# 31          P
# 32        NaN
# 33        NaN
# 34          P
# 35          P
# 36        NaN
# 37        NaN
# 38          P
# 39          P
# 40        NaN
# 41        NaN
# 42        NaN
# 43        NaN
# 44        NaN
# 45        NaN
# 46        NaN
# 47        NaN
# 48        NaN
# 49        NaN

# %%
df_econ.TIME.unique()
# Out:
# array([2018, 2019, 2020, 2021, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017,
#        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2022,
#        2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 1986, 1987, 1988,
#        1989], dtype=int64)

# %%
df_econ.INDICATOR.unique()
# Out:
# array(['GDP', 'GFCFSECTOR', 'CROPYIELD', 'AGRSUPP', 'EXCH', 'GNI',
#        'YRLIFELOST', 'OILPROD'], dtype=object)

# %%
df_econ.SUBJECT.unique()
# Out:
# array(['TOT', 'GG', 'RICE', 'WHEAT', 'MAIZE', 'SOYBEAN', 'TSE', 'PSE',
#        'CSE', 'GSSE'], dtype=object)

# %%
df_econ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33379 entries, 0 to 683
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    33379 non-null  object
#  1   INDICATOR   33379 non-null  object
#  2   SUBJECT     33379 non-null  object
#  3   MEASURE     33379 non-null  object
#  4   FREQUENCY   33379 non-null  object
#  5   TIME        33379 non-null  int64
#  6   Value       33379 non-null  float64
#  7   Flag Codes  197 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.3+ MB

# %%
# Remove dupliates 

df_econ2 = df_econ.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)

# %%
df_econ2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33251 entries, 0 to 683
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    33251 non-null  object
#  1   INDICATOR   33251 non-null  object
#  2   SUBJECT     33251 non-null  object
#  3   MEASURE     33251 non-null  object
#  4   FREQUENCY   33251 non-null  object
#  5   TIME        33251 non-null  int64
#  6   Value       33251 non-null  float64
#  7   Flag Codes  167 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 2.3+ MB

# %%
df_econ2.head(20)
# Out:
#    LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME         Value  \
# 0       AUT       GDP     TOT  USD_CAP         A  2018  56956.110562
# 1       AUT       GDP     TOT  USD_CAP         A  2019  59719.331647
# 2       AUT       GDP     TOT  USD_CAP         A  2020  57253.300563
# 3       AUT       GDP     TOT  USD_CAP         A  2021  59976.264665
# 4       BEL       GDP     TOT  USD_CAP         A  2018  52530.841510
# 5       BEL       GDP     TOT  USD_CAP         A  2019  55800.825988
# 6       BEL       GDP     TOT  USD_CAP         A  2020  54539.032525
# 7       BEL       GDP     TOT  USD_CAP         A  2021  58816.266983
# 8       CAN       GDP     TOT  USD_CAP         A  2018  49992.811418
# 9       CAN       GDP     TOT  USD_CAP         A  2019  49832.297981
# 10      CAN       GDP     TOT  USD_CAP         A  2020  47228.372488
# 11      CAN       GDP     TOT  USD_CAP         A  2021  53074.088264
# 12      CZE       GDP     TOT  USD_CAP         A  2018  41157.370409
# 13      CZE       GDP     TOT  USD_CAP         A  2019  44223.088155
# 14      CZE       GDP     TOT  USD_CAP         A  2020  42813.741340
# 15      CZE       GDP     TOT  USD_CAP         A  2021  44799.547333
# 16      DNK       GDP     TOT  USD_CAP         A  2018  57479.350221
# 17      DNK       GDP     TOT  USD_CAP         A  2019  59883.836280
# 18      DNK       GDP     TOT  USD_CAP         A  2020  60840.940164
# 19      DNK       GDP     TOT  USD_CAP         A  2021  64897.769113
#
#    Flag Codes
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6           P
# 7           P
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN

# %%
df_econ.LOCATION.unique()
# Out:
# array(['AUT', 'BEL', 'CAN', 'CZE', 'DNK', 'FIN', 'FRA', 'DEU', 'GRC',
#        'HUN', 'IRL', 'ITA', 'JPN', 'LUX', 'NLD', 'POL', 'PRT', 'SVK',
#        'ESP', 'SWE', 'GBR', 'USA', 'EST', 'SVN', 'OECD', 'LVA', 'LTU',
#        'BGR', 'HRV', 'CYP', 'MLT', 'ROU', 'AUS', 'KOR', 'MEX', 'NZL',
#        'TUR', 'ARG', 'BRA', 'CHL', 'CHN', 'COL', 'EGY', 'ETH', 'IND',
#        'IDN', 'IRN', 'KAZ', 'MYS', 'NGA', 'PAK', 'PRY', 'PER', 'PHL',
#        'RUS', 'SAU', 'ZAF', 'THA', 'UKR', 'VNM', 'WLD', 'BRICS', 'NOR',
#        'CHE', 'ISR', 'ISL', 'EU', 'CRI'], dtype=object)

# %%
# Add dataset to lookup to if a country is EU  or NOT. 
df_eulookup = pd.read_csv("DATA/EU_countries.csv")

df_eulookup.head(50)
# Out:
#    LOCATION       EU_Country  EU
# 0       AUT          Austria   1
# 1       BEL          Belgium   1
# 2       BGR         Bulgaria   1
# 3       HRV          Croatia   1
# 4       CYP           Cyprus   1
# 5       CZE   Czech Republic   1
# 6       DNK          Denmark   1
# 7       EST          Estonia   1
# 8       FIN          Finland   1
# 9       FRA           France   1
# 10      DEU          Germany   1
# 11      GRC           Greece   1
# 12      HUN          Hungary   1
# 13      IRL          Ireland   1
# 14      ITA            Italy   1
# 15      LVA           Latvia   1
# 16      LTU        Lithuania   1
# 17      LUX       Luxembourg   1
# 18      MLT            Malta   1
# 19      NLD      Netherlands   1
# 20      POL           Poland   1
# 21      PRT         Portugal   1
# 22      ROU          Romania   1
# 23      SVK  Slovak Republic   1
# 24      SVN         Slovenia   1
# 25      ESP            Spain   1
# 26      SWE           Sweden   1

# %%
# Add colum to say if Location is EU country, OECD benchark or otherwise. 
df_econ3 = df_econ2.join(df_eulookup.set_index('LOCATION'), on='LOCATION')
df_econ3.tail(100)
# Out:
#     LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME  Value Flag Codes  \
# 584      EST   OILPROD     TOT    KTOE         A  2008    0.0        NaN
# 585      EST   OILPROD     TOT    KTOE         A  2009    0.0        NaN
# 586      EST   OILPROD     TOT    KTOE         A  2010    0.0        NaN
# 587      EST   OILPROD     TOT    KTOE         A  2011    0.0        NaN
# 588      EST   OILPROD     TOT    KTOE         A  2012    0.0        NaN
# ..       ...       ...     ...     ...       ...   ...    ...        ...
# 679      CRI   OILPROD     TOT    KTOE         A  2013    0.0        NaN
# 680      CRI   OILPROD     TOT    KTOE         A  2014    0.0        NaN
# 681      CRI   OILPROD     TOT    KTOE         A  2015    0.0        NaN
# 682      CRI   OILPROD     TOT    KTOE         A  2016    0.0        NaN
# 683      CRI   OILPROD     TOT    KTOE         A  2017    0.0        NaN
#
#     EU_Country   EU
# 584    Estonia  1.0
# 585    Estonia  1.0
# 586    Estonia  1.0
# 587    Estonia  1.0
# 588    Estonia  1.0
# ..         ...  ...
# 679        NaN  NaN
# 680        NaN  NaN
# 681        NaN  NaN
# 682        NaN  NaN
# 683        NaN  NaN
#
# [100 rows x 10 columns]

# %%
df_econ3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33251 entries, 0 to 683
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   LOCATION    33251 non-null  object
#  1   INDICATOR   33251 non-null  object
#  2   SUBJECT     33251 non-null  object
#  3   MEASURE     33251 non-null  object
#  4   FREQUENCY   33251 non-null  object
#  5   TIME        33251 non-null  int64
#  6   Value       33251 non-null  float64
#  7   Flag Codes  167 non-null    object
#  8   EU_Country  2948 non-null   object
#  9   EU          2948 non-null   float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 2.8+ MB

# %%
# Filter out anything that's not EU 
df_econ4 = df_econ3[~df_econ3.EU.isnull()]

# %%
df_econ4.EU.unique()
# Out:
# array([1.])

# %%
df_econ4.TIME.unique()
# Out:
# array([2018, 2019, 2020, 2021, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017,
#        1996, 1997, 1998, 1999], dtype=int64)

# %%
# Mask formula to remove some that contains "-" from the new df

# year_mask = (df_econ3.TIME.str.find("-")==-1)
# df_econ3_year = df_econ3[year_mask]

# %%
df_econ4.head()
# Out:
#   LOCATION INDICATOR SUBJECT  MEASURE FREQUENCY  TIME         Value  \
# 0      AUT       GDP     TOT  USD_CAP         A  2018  56956.110562
# 1      AUT       GDP     TOT  USD_CAP         A  2019  59719.331647
# 2      AUT       GDP     TOT  USD_CAP         A  2020  57253.300563
# 3      AUT       GDP     TOT  USD_CAP         A  2021  59976.264665
# 4      BEL       GDP     TOT  USD_CAP         A  2018  52530.841510
#
#   Flag Codes EU_Country   EU
# 0        NaN    Austria  1.0
# 1        NaN    Austria  1.0
# 2        NaN    Austria  1.0
# 3        NaN    Austria  1.0
# 4        NaN    Belgium  1.0

# %%
#Export df to CSV
df_econ4.to_csv("df_econ_eu.csv")

# %%
df_econ3.TIME.unique()
# Out:
# array([2018, 2019, 2020, 2021, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017,
#        1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2022,
#        2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 1986, 1987, 1988,
#        1989], dtype=int64)

# %%
from pandas.core.reshape.pivot import pivot

# %%
pd.pivot_table(df_econ3, values = 'Value', index=['LOCATION','TIME'], columns = 'INDICATOR').reset_index()
# Out:
# INDICATOR LOCATION  TIME  AGRSUPP    CROPYIELD  EXCH  GDP  GFCFSECTOR  GNI  \
# 0              ARG  1990      NaN  3592.324250   NaN  NaN         NaN  NaN
# 1              ARG  1991      NaN  3685.865750   NaN  NaN         NaN  NaN
# 2              ARG  1992      NaN  3708.984667   NaN  NaN         NaN  NaN
# 3              ARG  1993      NaN  3782.307667   NaN  NaN         NaN  NaN
# 4              ARG  1994      NaN  4102.401917   NaN  NaN         NaN  NaN
# ...            ...   ...      ...          ...   ...  ...         ...  ...
# 2366           ZAF  2026      NaN  2143.978167   NaN  NaN         NaN  NaN
# 2367           ZAF  2027      NaN  2175.352500   NaN  NaN         NaN  NaN
# 2368           ZAF  2028      NaN  2206.567750   NaN  NaN         NaN  NaN
# 2369           ZAF  2029      NaN  2239.788250   NaN  NaN         NaN  NaN
# 2370           ZAF  2030      NaN  2275.879083   NaN  NaN         NaN  NaN
#
# INDICATOR  OILPROD  YRLIFELOST
# 0              NaN         NaN
# 1              NaN         NaN
# 2              NaN         NaN
# 3              NaN         NaN
# 4              NaN         NaN
# ...            ...         ...
# 2366           NaN         NaN
# 2367           NaN         NaN
# 2368           NaN         NaN
# 2369           NaN         NaN
# 2370           NaN         NaN
#
# [2371 rows x 10 columns]

# %% [markdown]
# ## Now the Farming Dataset

# %%
df_farm = pd.read_csv("DATA/FAOSTAT_data_en_12-16-2022.csv")

# %%
df_farm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40906 entries, 0 to 40905
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       40906 non-null  object
#  1   Domain            40906 non-null  object
#  2   Area Code (M49)   40906 non-null  int64
#  3   Area              40906 non-null  object
#  4   Element Code      40906 non-null  int64
#  5   Element           40906 non-null  object
#  6   Item Code (CPC)   40906 non-null  object
#  7   Item              40906 non-null  object
#  8   Year Code         40906 non-null  int64
#  9   Year              40906 non-null  int64
#  10  Unit              40906 non-null  object
#  11  Value             38734 non-null  float64
#  12  Flag              40906 non-null  object
#  13  Flag Description  40906 non-null  object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 4.4+ MB

# %%
df_farm.describe()
# Out:
#        Area Code (M49)  Element Code     Year Code          Year         Value
# count     40906.000000  40906.000000  40906.000000  40906.000000  3.873400e+04
# mean        440.027942   5407.513299   2018.420721   2018.420721  4.487460e+05
# std         246.782100    101.030220      1.106960      1.106960  2.682921e+06
# min           8.000000   5111.000000   2017.000000   2017.000000  0.000000e+00
# 25%         233.000000   5312.000000   2017.000000   2017.000000  7.190000e+02
# 50%         440.000000   5419.000000   2018.000000   2018.000000  1.455200e+04
# 75%         643.000000   5510.000000   2019.000000   2019.000000  9.609150e+04
# max         826.000000   5513.000000   2020.000000   2020.000000  8.600254e+07

# %%
df_farm.head(50)
# Out:
#    Domain Code                        Domain  Area Code (M49)     Area  \
# 0          QCL  Crops and livestock products                8  Albania
# 1          QCL  Crops and livestock products                8  Albania
# 2          QCL  Crops and livestock products                8  Albania
# 3          QCL  Crops and livestock products                8  Albania
# 4          QCL  Crops and livestock products                8  Albania
# 5          QCL  Crops and livestock products                8  Albania
# 6          QCL  Crops and livestock products                8  Albania
# 7          QCL  Crops and livestock products                8  Albania
# 8          QCL  Crops and livestock products                8  Albania
# 9          QCL  Crops and livestock products                8  Albania
# 10         QCL  Crops and livestock products                8  Albania
# 11         QCL  Crops and livestock products                8  Albania
# 12         QCL  Crops and livestock products                8  Albania
# 13         QCL  Crops and livestock products                8  Albania
# 14         QCL  Crops and livestock products                8  Albania
# 15         QCL  Crops and livestock products                8  Albania
# 16         QCL  Crops and livestock products                8  Albania
# 17         QCL  Crops and livestock products                8  Albania
# 18         QCL  Crops and livestock products                8  Albania
# 19         QCL  Crops and livestock products                8  Albania
# 20         QCL  Crops and livestock products                8  Albania
# 21         QCL  Crops and livestock products                8  Albania
# 22         QCL  Crops and livestock products                8  Albania
# 23         QCL  Crops and livestock products                8  Albania
# 24         QCL  Crops and livestock products                8  Albania
# 25         QCL  Crops and livestock products                8  Albania
# 26         QCL  Crops and livestock products                8  Albania
# 27         QCL  Crops and livestock products                8  Albania
# 28         QCL  Crops and livestock products                8  Albania
# 29         QCL  Crops and livestock products                8  Albania
# 30         QCL  Crops and livestock products                8  Albania
# 31         QCL  Crops and livestock products                8  Albania
# 32         QCL  Crops and livestock products                8  Albania
# 33         QCL  Crops and livestock products                8  Albania
# 34         QCL  Crops and livestock products                8  Albania
# 35         QCL  Crops and livestock products                8  Albania
# 36         QCL  Crops and livestock products                8  Albania
# 37         QCL  Crops and livestock products                8  Albania
# 38         QCL  Crops and livestock products                8  Albania
# 39         QCL  Crops and livestock products                8  Albania
# 40         QCL  Crops and livestock products                8  Albania
# 41         QCL  Crops and livestock products                8  Albania
# 42         QCL  Crops and livestock products                8  Albania
# 43         QCL  Crops and livestock products                8  Albania
# 44         QCL  Crops and livestock products                8  Albania
# 45         QCL  Crops and livestock products                8  Albania
# 46         QCL  Crops and livestock products                8  Albania
# 47         QCL  Crops and livestock products                8  Albania
# 48         QCL  Crops and livestock products                8  Albania
# 49         QCL  Crops and livestock products                8  Albania
#
#     Element Code         Element Item Code (CPC)        Item  Year Code  Year  \
# 0           5312  Area harvested            1341      Apples       2017  2017
# 1           5312  Area harvested            1341      Apples       2018  2018
# 2           5312  Area harvested            1341      Apples       2019  2019
# 3           5312  Area harvested            1341      Apples       2020  2020
# 4           5419           Yield            1341      Apples       2017  2017
# 5           5419           Yield            1341      Apples       2018  2018
# 6           5419           Yield            1341      Apples       2019  2019
# 7           5419           Yield            1341      Apples       2020  2020
# 8           5510      Production            1341      Apples       2017  2017
# 9           5510      Production            1341      Apples       2018  2018
# 10          5510      Production            1341      Apples       2019  2019
# 11          5510      Production            1341      Apples       2020  2020
# 12          5312  Area harvested            1343    Apricots       2017  2017
# 13          5312  Area harvested            1343    Apricots       2018  2018
# 14          5312  Area harvested            1343    Apricots       2019  2019
# 15          5312  Area harvested            1343    Apricots       2020  2020
# 16          5419           Yield            1343    Apricots       2017  2017
# 17          5419           Yield            1343    Apricots       2018  2018
# 18          5419           Yield            1343    Apricots       2019  2019
# 19          5419           Yield            1343    Apricots       2020  2020
# 20          5510      Production            1343    Apricots       2017  2017
# 21          5510      Production            1343    Apricots       2018  2018
# 22          5510      Production            1343    Apricots       2019  2019
# 23          5510      Production            1343    Apricots       2020  2020
# 24          5111          Stocks            2132       Asses       2017  2017
# 25          5111          Stocks            2132       Asses       2018  2018
# 26          5111          Stocks            2132       Asses       2019  2019
# 27          5111          Stocks            2132       Asses       2020  2020
# 28          5312  Area harvested             115      Barley       2017  2017
# 29          5312  Area harvested             115      Barley       2018  2018
# 30          5312  Area harvested             115      Barley       2019  2019
# 31          5312  Area harvested             115      Barley       2020  2020
# 32          5419           Yield             115      Barley       2017  2017
# 33          5419           Yield             115      Barley       2018  2018
# 34          5419           Yield             115      Barley       2019  2019
# 35          5419           Yield             115      Barley       2020  2020
# 36          5510      Production             115      Barley       2017  2017
# 37          5510      Production             115      Barley       2018  2018
# 38          5510      Production             115      Barley       2019  2019
# 39          5510      Production             115      Barley       2020  2020
# 40          5312  Area harvested            1701  Beans, dry       2017  2017
# 41          5312  Area harvested            1701  Beans, dry       2018  2018
# 42          5312  Area harvested            1701  Beans, dry       2019  2019
# 43          5312  Area harvested            1701  Beans, dry       2020  2020
# 44          5419           Yield            1701  Beans, dry       2017  2017
# 45          5419           Yield            1701  Beans, dry       2018  2018
# 46          5419           Yield            1701  Beans, dry       2019  2019
# 47          5419           Yield            1701  Beans, dry       2020  2020
# 48          5510      Production            1701  Beans, dry       2017  2017
# 49          5510      Production            1701  Beans, dry       2018  2018
#
#       Unit     Value Flag   Flag Description
# 0       ha    4346.0    A    Official figure
# 1       ha    4294.0    A    Official figure
# 2       ha    4407.0    A    Official figure
# 3       ha    4420.0    A    Official figure
# 4    hg/ha  221671.0    E    Estimated value
# 5    hg/ha  252387.0    E    Estimated value
# 6    hg/ha  240374.0    E    Estimated value
# 7    hg/ha  231147.0    E    Estimated value
# 8   tonnes   96338.0    A    Official figure
# 9   tonnes  108375.0    A    Official figure
# 10  tonnes  105933.0    A    Official figure
# 11  tonnes  102167.0    A    Official figure
# 12      ha     326.0    A    Official figure
# 13      ha     337.0    A    Official figure
# 14      ha     341.0    A    Official figure
# 15      ha     346.0    A    Official figure
# 16   hg/ha  154601.0    E    Estimated value
# 17   hg/ha  152493.0    E    Estimated value
# 18   hg/ha  142962.0    E    Estimated value
# 19   hg/ha  148642.0    E    Estimated value
# 20  tonnes    5040.0    A    Official figure
# 21  tonnes    5139.0    A    Official figure
# 22  tonnes    4875.0    A    Official figure
# 23  tonnes    5143.0    A    Official figure
# 24    Head   56000.0    T  Unofficial figure
# 25    Head   56000.0    T  Unofficial figure
# 26    Head   55000.0    T  Unofficial figure
# 27    Head   49000.0    T  Unofficial figure
# 28      ha    3065.0    A    Official figure
# 29      ha    3397.0    A    Official figure
# 30      ha    2742.0    A    Official figure
# 31      ha    3771.0    A    Official figure
# 32   hg/ha   29478.0    E    Estimated value
# 33   hg/ha   28422.0    E    Estimated value
# 34   hg/ha   28964.0    E    Estimated value
# 35   hg/ha   33532.0    E    Estimated value
# 36  tonnes    9035.0    A    Official figure
# 37  tonnes    9655.0    A    Official figure
# 38  tonnes    7942.0    A    Official figure
# 39  tonnes   12645.0    A    Official figure
# 40      ha   13041.0    A    Official figure
# 41      ha   13373.0    A    Official figure
# 42      ha   13550.0    A    Official figure
# 43      ha   13346.0    A    Official figure
# 44   hg/ha   16256.0    E    Estimated value
# 45   hg/ha   18352.0    E    Estimated value
# 46   hg/ha   18289.0    E    Estimated value
# 47   hg/ha   17193.0    E    Estimated value
# 48  tonnes   21200.0    A    Official figure
# 49  tonnes   24542.0    A    Official figure

# %%
df_farm.Year.unique()
# Out:
# array([2017, 2018, 2019, 2020], dtype=int64)

# %%
df_farm.Area.unique()
# Out:
# array(['Albania', 'Austria', 'Belarus', 'Belgium',
#        'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Czechia',
#        'Denmark', 'Estonia', 'Faroe Islands', 'Finland', 'France',
#        'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy',
#        'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Montenegro',
#        'Netherlands', 'North Macedonia', 'Norway', 'Poland', 'Portugal',
#        'Republic of Moldova', 'Romania', 'Russian Federation', 'Serbia',
#        'Slovakia', 'Slovenia', 'Spain', 'Sweden', 'Switzerland',
#        'Ukraine', 'United Kingdom of Great Britain and Northern Ireland'],
#       dtype=object)

# %%
df_farm.Domain.unique()
# Out:
# array(['Crops and livestock products'], dtype=object)

# %%
# print(df_farm.Item.unique())

# %%
# Add colum to say if Location is EU country, OECD benchark or otherwise. 
df_farm2 = df_farm.join(df_eulookup.set_index('EU_Country'), on='Area')

# %%
df_farm2.head(50)
# Out:
#    Domain Code                        Domain  Area Code (M49)     Area  \
# 0          QCL  Crops and livestock products                8  Albania
# 1          QCL  Crops and livestock products                8  Albania
# 2          QCL  Crops and livestock products                8  Albania
# 3          QCL  Crops and livestock products                8  Albania
# 4          QCL  Crops and livestock products                8  Albania
# 5          QCL  Crops and livestock products                8  Albania
# 6          QCL  Crops and livestock products                8  Albania
# 7          QCL  Crops and livestock products                8  Albania
# 8          QCL  Crops and livestock products                8  Albania
# 9          QCL  Crops and livestock products                8  Albania
# 10         QCL  Crops and livestock products                8  Albania
# 11         QCL  Crops and livestock products                8  Albania
# 12         QCL  Crops and livestock products                8  Albania
# 13         QCL  Crops and livestock products                8  Albania
# 14         QCL  Crops and livestock products                8  Albania
# 15         QCL  Crops and livestock products                8  Albania
# 16         QCL  Crops and livestock products                8  Albania
# 17         QCL  Crops and livestock products                8  Albania
# 18         QCL  Crops and livestock products                8  Albania
# 19         QCL  Crops and livestock products                8  Albania
# 20         QCL  Crops and livestock products                8  Albania
# 21         QCL  Crops and livestock products                8  Albania
# 22         QCL  Crops and livestock products                8  Albania
# 23         QCL  Crops and livestock products                8  Albania
# 24         QCL  Crops and livestock products                8  Albania
# 25         QCL  Crops and livestock products                8  Albania
# 26         QCL  Crops and livestock products                8  Albania
# 27         QCL  Crops and livestock products                8  Albania
# 28         QCL  Crops and livestock products                8  Albania
# 29         QCL  Crops and livestock products                8  Albania
# 30         QCL  Crops and livestock products                8  Albania
# 31         QCL  Crops and livestock products                8  Albania
# 32         QCL  Crops and livestock products                8  Albania
# 33         QCL  Crops and livestock products                8  Albania
# 34         QCL  Crops and livestock products                8  Albania
# 35         QCL  Crops and livestock products                8  Albania
# 36         QCL  Crops and livestock products                8  Albania
# 37         QCL  Crops and livestock products                8  Albania
# 38         QCL  Crops and livestock products                8  Albania
# 39         QCL  Crops and livestock products                8  Albania
# 40         QCL  Crops and livestock products                8  Albania
# 41         QCL  Crops and livestock products                8  Albania
# 42         QCL  Crops and livestock products                8  Albania
# 43         QCL  Crops and livestock products                8  Albania
# 44         QCL  Crops and livestock products                8  Albania
# 45         QCL  Crops and livestock products                8  Albania
# 46         QCL  Crops and livestock products                8  Albania
# 47         QCL  Crops and livestock products                8  Albania
# 48         QCL  Crops and livestock products                8  Albania
# 49         QCL  Crops and livestock products                8  Albania
#
#     Element Code         Element Item Code (CPC)        Item  Year Code  Year  \
# 0           5312  Area harvested            1341      Apples       2017  2017
# 1           5312  Area harvested            1341      Apples       2018  2018
# 2           5312  Area harvested            1341      Apples       2019  2019
# 3           5312  Area harvested            1341      Apples       2020  2020
# 4           5419           Yield            1341      Apples       2017  2017
# 5           5419           Yield            1341      Apples       2018  2018
# 6           5419           Yield            1341      Apples       2019  2019
# 7           5419           Yield            1341      Apples       2020  2020
# 8           5510      Production            1341      Apples       2017  2017
# 9           5510      Production            1341      Apples       2018  2018
# 10          5510      Production            1341      Apples       2019  2019
# 11          5510      Production            1341      Apples       2020  2020
# 12          5312  Area harvested            1343    Apricots       2017  2017
# 13          5312  Area harvested            1343    Apricots       2018  2018
# 14          5312  Area harvested            1343    Apricots       2019  2019
# 15          5312  Area harvested            1343    Apricots       2020  2020
# 16          5419           Yield            1343    Apricots       2017  2017
# 17          5419           Yield            1343    Apricots       2018  2018
# 18          5419           Yield            1343    Apricots       2019  2019
# 19          5419           Yield            1343    Apricots       2020  2020
# 20          5510      Production            1343    Apricots       2017  2017
# 21          5510      Production            1343    Apricots       2018  2018
# 22          5510      Production            1343    Apricots       2019  2019
# 23          5510      Production            1343    Apricots       2020  2020
# 24          5111          Stocks            2132       Asses       2017  2017
# 25          5111          Stocks            2132       Asses       2018  2018
# 26          5111          Stocks            2132       Asses       2019  2019
# 27          5111          Stocks            2132       Asses       2020  2020
# 28          5312  Area harvested             115      Barley       2017  2017
# 29          5312  Area harvested             115      Barley       2018  2018
# 30          5312  Area harvested             115      Barley       2019  2019
# 31          5312  Area harvested             115      Barley       2020  2020
# 32          5419           Yield             115      Barley       2017  2017
# 33          5419           Yield             115      Barley       2018  2018
# 34          5419           Yield             115      Barley       2019  2019
# 35          5419           Yield             115      Barley       2020  2020
# 36          5510      Production             115      Barley       2017  2017
# 37          5510      Production             115      Barley       2018  2018
# 38          5510      Production             115      Barley       2019  2019
# 39          5510      Production             115      Barley       2020  2020
# 40          5312  Area harvested            1701  Beans, dry       2017  2017
# 41          5312  Area harvested            1701  Beans, dry       2018  2018
# 42          5312  Area harvested            1701  Beans, dry       2019  2019
# 43          5312  Area harvested            1701  Beans, dry       2020  2020
# 44          5419           Yield            1701  Beans, dry       2017  2017
# 45          5419           Yield            1701  Beans, dry       2018  2018
# 46          5419           Yield            1701  Beans, dry       2019  2019
# 47          5419           Yield            1701  Beans, dry       2020  2020
# 48          5510      Production            1701  Beans, dry       2017  2017
# 49          5510      Production            1701  Beans, dry       2018  2018
#
#       Unit     Value Flag   Flag Description LOCATION  EU
# 0       ha    4346.0    A    Official figure      NaN NaN
# 1       ha    4294.0    A    Official figure      NaN NaN
# 2       ha    4407.0    A    Official figure      NaN NaN
# 3       ha    4420.0    A    Official figure      NaN NaN
# 4    hg/ha  221671.0    E    Estimated value      NaN NaN
# 5    hg/ha  252387.0    E    Estimated value      NaN NaN
# 6    hg/ha  240374.0    E    Estimated value      NaN NaN
# 7    hg/ha  231147.0    E    Estimated value      NaN NaN
# 8   tonnes   96338.0    A    Official figure      NaN NaN
# 9   tonnes  108375.0    A    Official figure      NaN NaN
# 10  tonnes  105933.0    A    Official figure      NaN NaN
# 11  tonnes  102167.0    A    Official figure      NaN NaN
# 12      ha     326.0    A    Official figure      NaN NaN
# 13      ha     337.0    A    Official figure      NaN NaN
# 14      ha     341.0    A    Official figure      NaN NaN
# 15      ha     346.0    A    Official figure      NaN NaN
# 16   hg/ha  154601.0    E    Estimated value      NaN NaN
# 17   hg/ha  152493.0    E    Estimated value      NaN NaN
# 18   hg/ha  142962.0    E    Estimated value      NaN NaN
# 19   hg/ha  148642.0    E    Estimated value      NaN NaN
# 20  tonnes    5040.0    A    Official figure      NaN NaN
# 21  tonnes    5139.0    A    Official figure      NaN NaN
# 22  tonnes    4875.0    A    Official figure      NaN NaN
# 23  tonnes    5143.0    A    Official figure      NaN NaN
# 24    Head   56000.0    T  Unofficial figure      NaN NaN
# 25    Head   56000.0    T  Unofficial figure      NaN NaN
# 26    Head   55000.0    T  Unofficial figure      NaN NaN
# 27    Head   49000.0    T  Unofficial figure      NaN NaN
# 28      ha    3065.0    A    Official figure      NaN NaN
# 29      ha    3397.0    A    Official figure      NaN NaN
# 30      ha    2742.0    A    Official figure      NaN NaN
# 31      ha    3771.0    A    Official figure      NaN NaN
# 32   hg/ha   29478.0    E    Estimated value      NaN NaN
# 33   hg/ha   28422.0    E    Estimated value      NaN NaN
# 34   hg/ha   28964.0    E    Estimated value      NaN NaN
# 35   hg/ha   33532.0    E    Estimated value      NaN NaN
# 36  tonnes    9035.0    A    Official figure      NaN NaN
# 37  tonnes    9655.0    A    Official figure      NaN NaN
# 38  tonnes    7942.0    A    Official figure      NaN NaN
# 39  tonnes   12645.0    A    Official figure      NaN NaN
# 40      ha   13041.0    A    Official figure      NaN NaN
# 41      ha   13373.0    A    Official figure      NaN NaN
# 42      ha   13550.0    A    Official figure      NaN NaN
# 43      ha   13346.0    A    Official figure      NaN NaN
# 44   hg/ha   16256.0    E    Estimated value      NaN NaN
# 45   hg/ha   18352.0    E    Estimated value      NaN NaN
# 46   hg/ha   18289.0    E    Estimated value      NaN NaN
# 47   hg/ha   17193.0    E    Estimated value      NaN NaN
# 48  tonnes   21200.0    A    Official figure      NaN NaN
# 49  tonnes   24542.0    A    Official figure      NaN NaN

# %%
df_farm3 = df_farm2[df_farm2['EU'] > 0]

# %%
df_farm3.head(150)
# Out:
#      Domain Code                        Domain  Area Code (M49)     Area  \
# 1104         QCL  Crops and livestock products               40  Austria
# 1105         QCL  Crops and livestock products               40  Austria
# 1106         QCL  Crops and livestock products               40  Austria
# 1107         QCL  Crops and livestock products               40  Austria
# 1108         QCL  Crops and livestock products               40  Austria
# ...          ...                           ...              ...      ...
# 1249         QCL  Crops and livestock products               40  Austria
# 1250         QCL  Crops and livestock products               40  Austria
# 1251         QCL  Crops and livestock products               40  Austria
# 1252         QCL  Crops and livestock products               40  Austria
# 1253         QCL  Crops and livestock products               40  Austria
#
#       Element Code         Element Item Code (CPC)                       Item  \
# 1104          5312  Area harvested            1341                     Apples
# 1105          5312  Area harvested            1341                     Apples
# 1106          5312  Area harvested            1341                     Apples
# 1107          5312  Area harvested            1341                     Apples
# 1108          5419           Yield            1341                     Apples
# ...            ...             ...             ...                        ...
# 1249          5312  Area harvested            1213  Cauliflowers and broccoli
# 1250          5312  Area harvested            1213  Cauliflowers and broccoli
# 1251          5312  Area harvested            1213  Cauliflowers and broccoli
# 1252          5312  Area harvested            1213  Cauliflowers and broccoli
# 1253          5419           Yield            1213  Cauliflowers and broccoli
#
#       Year Code  Year   Unit     Value Flag Flag Description LOCATION   EU
# 1104       2017  2017     ha       NaN    A  Official figure      AUT  1.0
# 1105       2018  2018     ha    6740.0    A  Official figure      AUT  1.0
# 1106       2019  2019     ha    6590.0    A  Official figure      AUT  1.0
# 1107       2020  2020     ha    6430.0    A  Official figure      AUT  1.0
# 1108       2018  2018  hg/ha  575593.0    E  Estimated value      AUT  1.0
# ...         ...   ...    ...       ...  ...              ...      ...  ...
# 1249       2017  2017     ha     284.0    A  Official figure      AUT  1.0
# 1250       2018  2018     ha     260.0    A  Official figure      AUT  1.0
# 1251       2019  2019     ha     280.0    A  Official figure      AUT  1.0
# 1252       2020  2020     ha     320.0    A  Official figure      AUT  1.0
# 1253       2017  2017  hg/ha  207183.0    E  Estimated value      AUT  1.0
#
# [150 rows x 16 columns]

# %%
# pd.pivot_table(df_farm2, values = 'Value', index=['Area','Year'], columns = 'Domain').reset_index()
# pd.pivot_table(df_farm2, values = 'Value', index=['Area','Year'], columns = 'Item', Filter = "EU" = 1)

# %%
#Write to csv
df_farm3.to_csv("df_farm3.csv")

# %%
# Filter out anything that's not EU 
df_farm_eu = df_farm3[~df_farm3.EU.isnull()]

# %%
df_farm_eu.head()
# Out:
#      Domain Code                        Domain  Area Code (M49)     Area  \
# 1104         QCL  Crops and livestock products               40  Austria
# 1105         QCL  Crops and livestock products               40  Austria
# 1106         QCL  Crops and livestock products               40  Austria
# 1107         QCL  Crops and livestock products               40  Austria
# 1108         QCL  Crops and livestock products               40  Austria
#
#       Element Code         Element Item Code (CPC)    Item  Year Code  Year  \
# 1104          5312  Area harvested            1341  Apples       2017  2017
# 1105          5312  Area harvested            1341  Apples       2018  2018
# 1106          5312  Area harvested            1341  Apples       2019  2019
# 1107          5312  Area harvested            1341  Apples       2020  2020
# 1108          5419           Yield            1341  Apples       2018  2018
#
#        Unit     Value Flag Flag Description LOCATION   EU
# 1104     ha       NaN    A  Official figure      AUT  1.0
# 1105     ha    6740.0    A  Official figure      AUT  1.0
# 1106     ha    6590.0    A  Official figure      AUT  1.0
# 1107     ha    6430.0    A  Official figure      AUT  1.0
# 1108  hg/ha  575593.0    E  Estimated value      AUT  1.0

# %%
#Write to csv
df_farm_eu.to_csv("df_farm_eu.csv")

# %%
## Price Data Processing

# %%
## Input European Data

df_price1 = pd.read_csv("DATA\Prices_E_Europe\Prices_E_Europe.csv")

# %%
df_price1.head()
# Out:
#    Area Code Area Code (M49)     Area  Item Code Item Code (CPC)    Item  \
# 0          3            '008  Albania        515          '01341  Apples
# 1          3            '008  Albania        515          '01341  Apples
# 2          3            '008  Albania        515          '01341  Apples
# 3          3            '008  Albania        515          '01341  Apples
# 4          3            '008  Albania        515          '01341  Apples
#
#    Element Code                     Element  Months Code        Months  ...  \
# 0          5530  Producer Price (LCU/tonne)         7021  Annual value  ...
# 1          5530  Producer Price (LCU/tonne)         7001       January  ...
# 2          5530  Producer Price (LCU/tonne)         7002      February  ...
# 3          5530  Producer Price (LCU/tonne)         7003         March  ...
# 4          5530  Producer Price (LCU/tonne)         7004         April  ...
#
#       2017  2017F     2018  2018F     2019  2019F     2020  2020F 2021  2021F
# 0  54979.4      A  46997.7      A  38086.7      A  55447.0      A  NaN    NaN
# 1  46325.0      A  53970.0      A  37244.0      A  43790.0      A  NaN    NaN
# 2  47902.0      A  54079.0      A  34500.0      A  45990.0      A  NaN    NaN
# 3  52224.0      A  62985.0      A  37087.0      A  41865.0      A  NaN    NaN
# 4  62325.0      A  66062.0      A  37017.0      A  67172.0      A  NaN    NaN
#
# [5 rows x 73 columns]

# %%
df_price2 = df_price1.melt()

# %%
df_price2.melt()
# Out:
# C:\Users\megan.c.mchugh\AppData\Local\Temp\ipykernel_20920\1298159081.py:1: FutureWarning: This dataframe has a column name that matches the 'value_name' column name of the resulting Dataframe. In the future this will raise an error, please set the 'value_name' parameter of DataFrame.melt to a unique name.
#   df_price2.melt()
#          variable      value
# 0        variable  Area Code
# 1        variable  Area Code
# 2        variable  Area Code
# 3        variable  Area Code
# 4        variable  Area Code
# ...           ...        ...
# 3368069     value          I
# 3368070     value          I
# 3368071     value          I
# 3368072     value          I
# 3368073     value          I
#
# [3368074 rows x 2 columns]

# %%
df_price2.head(150)
# Out:
#       variable value
# 0    Area Code     3
# 1    Area Code     3
# 2    Area Code     3
# 3    Area Code     3
# 4    Area Code     3
# ..         ...   ...
# 145  Area Code     3
# 146  Area Code     3
# 147  Area Code     3
# 148  Area Code     3
# 149  Area Code     3
#
# [150 rows x 2 columns]

# %%
pd.read_csv("DATA\\Prices_E_All_Data\\Prices_E_All_Data_NOFLAG.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [71], in <cell line: 1>()
# ----> 1 pd.read_csv("DATA\\Prices_E_All_Data\\Prices_E_All_Data_NOFLAG.csv")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1254, in TextFileReader.read(self, nrows)
#    1252 nrows = validate_integer("nrows", nrows)
#    1253 try:
# -> 1254     index, columns, col_dict = self._engine.read(nrows)
#    1255 except Exception:
#    1256     self.close()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:1952, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 137975: invalid continuation byte

# %%
df_trade1 = pd.read_csv("DATA/Trade_CropsLivestock_E_All_Data/Trade_CropsLivestock_E_All_Data.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [63], in <cell line: 1>()
# ----> 1 df_trade1 = pd.read_csv("DATA/Trade_CropsLivestock_E_All_Data/Trade_CropsLivestock_E_All_Data.csv")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1235, in TextFileReader._make_engine(self, f, engine)
#    1232     raise ValueError(msg)
#    1234 try:
# -> 1235     return mapping[engine](f, **self.options)
#    1236 except Exception:
#    1237     if self.handles is not None:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:75, in CParserWrapper.__init__(self, src, **kwds)
#      72     kwds.pop(key, None)
#      74 kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 75 self._reader = parsers.TextReader(src, **kwds)
#      77 self.unnamed_cols = self._reader.unnamed_cols
#      79 # error: Cannot determine type of 'names'
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:544, in pandas._libs.parsers.TextReader.__cinit__()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:633, in pandas._libs.parsers.TextReader._get_header()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\parsers.pyx:1952, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 165398: invalid continuation byte

# %% [markdown]
# ## Combine farming and econ dfs?

# %% [markdown]
# ## Getting Started with Interactive Data Visualizations

# %%
# Sample 



# import pandas as pd
# import numpy as np

# %%
co2 = pd.read_csv('data/co2.csv')
co2.head()

gm = pd.read_csv('data/gapminder.csv')
gm.head()

df_gm = gm[['Country', 'region']].drop_duplicates()

df_w_regions = pd.merge(co2, df_gm, left_on='country', right_on='Country', how='inner')

df_w_regions = df_w_regions.drop('Country', axis='columns')

new_co2 = pd.melt(df_w_regions, id_vars=['country', 'region'])

columns = ['country', 'region', 'year', 'co2']
new_co2.columns = columns

df_co2 = new_co2[new_co2['year'].astype('int64') > 1963]
df_co2 = df_co2.sort_values(by=['country', 'year'])
df_co2['year'] = df_co2['year'].astype('int64')
df_co2.head()

df_gdp = gm[['Country', 'Year', 'gdp']]
df_gdp.columns = ['country', 'year', 'gdp']
df_gdp.head()

data = pd.merge(df_co2, df_gdp, on=['country', 'year'], how='left')

data = data.dropna()
data.head()

np_co2 = np.array(data['co2'])
np_gdp = np.array(data['gdp'])
np.corrcoef(np_co2, np_gdp)

from bokeh.io import curdoc, output_notebook
from bokeh.plotting import figure, show
from bokeh.models import HoverTool, ColumnDataSource, CategoricalColorMapper, Slider
from bokeh.palettes import Spectral6
from bokeh.layouts import widgetbox, row

output_notebook()

regions_list = data.region.unique().tolist()
color_mapper = CategoricalColorMapper(factors=regions_list, palette=Spectral6)

Make the ColumnDataSource: source


source = ColumnDataSource(data={
    'x': data.gdp[data['year'] == 1964],
    'y': data.co2[data['year'] == 1964],
    'country': data.country[data['year'] == 1964],
    'region': data.region[data['year'] == 1964],
})

Save the minimum and maximum values of the gdp column: xmin, xmax

xmin, xmax = min(data.gdp), max(data.gdp)

Save the minimum and maximum values of the co2 column: ymin, ymax

ymin, ymax = min(data.co2), max(data.co2)

Create the figure: plot


plot = figure(title='CO2 Emissions vs GDP in 1964', 
              plot_height=600, plot_width=1000,
              x_range=(xmin, xmax),
              y_range=(ymin, ymax), y_axis_type='log')

Add circle glyphs to the plot

plot.circle(x='x', y='y', fill_alpha=0.8, source=source, legend='region',
            color=dict(field='region', transform=color_mapper),
            size=7)

# Set the legend.location attribute of the plot
plot.legend.location = 'bottom_right'

# Set the x-axis label
plot.xaxis.axis_label = 'Income Per Person'

# Set the y-axis label
plot.yaxis.axis_label = 'CO2 Emissions (tons per person)'

show(plot)

### Adding a Slider to the Static Plot 

slider = Slider(start=min(data.year), end=max(data.year), step=1,
value=min(data.year), title='Year') 

def update_plot(attr, old, new):
    yr = slider.value
    new_data = {
     'x': data.gdp[data['year'] == yr], 
     'y': data.co2[data['year'] == yr],
     'country': data.country[data['year'] == yr],
     'region': data.region[data['year'] == yr],
    }
    source.data = new_data
    plot.title.text = 'CO2 Emissions vs GDP in %d' % yr 

slider.on_change('value', update_plot)

layout = row(widgetbox(slider), plot) 

curdoc().add_root(layout) 

### Adding a Hover Tool 

hover = HoverTool(tooltips=[('Country', '@country'), ('GDP', '@x'), ('CO2 Emission','@y')]) 

plot.add_tools(hover) 

# !bokeh serve --show Getting_Started_with_Interactive_Data_Visualizations.ipynb

## Interactive Data Visualization with Plotly Express 

import pandas as pd
import plotly.express as px 

co2 = pd.read_csv('data/co2.csv')
gm = pd.read_csv('data/gapminder.csv')

df_gm = gm[['Country', 'region']].drop_duplicates()
df_w_regions = pd.merge(co2, df_gm, left_on='country', right_on='Country',how='inner')
df_w_regions = df_w_regions.drop('Country', axis='columns')
new_co2 = pd.melt(df_w_regions, id_vars=['country', 'region'])
columns = ['country', 'region', 'year', 'co2']
new_co2.columns = columns
df_co2 = new_co2[new_co2['year'].astype('int64') > 1963]
df_co2 = df_co2.sort_values(by=['country', 'year'])
df_co2['year'] = df_co2['year'].astype('int64')
df_gdp = gm[['Country', 'Year', 'gdp']]
df_gdp.columns = ['country', 'year', 'gdp']
data = pd.merge(df_co2, df_gdp, on=['country', 'year'], how='left') 
data = data.dropna() 

data.head() 


xmin, xmax = min(data.gdp), max(data.gdp) 

ymin, ymax = min(data.co2), max(data.co2) 

fig = px.scatter(data, x="gdp", y="co2", animation_frame="year",
animation_group="country", color="region", hover_name="country",
facet_col="region", width=1579, height=400, log_x=True, size_max=45,
range_x=[xmin,xmax], range_y=[ymin,ymax]) 


fig.show()
